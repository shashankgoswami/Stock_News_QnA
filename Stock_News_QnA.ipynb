# %% [markdown]
# ## 0.Install Libraries

# %%
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (4.53.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (1.16.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (0.33.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence_transformers) (4.14.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence_transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2025.7.14)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 860.2 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.0.15-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.11/dist-packages (from chromadb) (2.11.7)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp311-cp311-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb) (2.0.2)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.14.1)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.35.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.35.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.35.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.21.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 1.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.74.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.16.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb) (3.11.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.25.0)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (0.26.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.35.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.35.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.35.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.35.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.56b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.56b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.2->chromadb) (0.33.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.5)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading chromadb-1.0.15-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 75.2 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 16.5 MB/s eta 0:00:00
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 62.7 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 83.2 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.35.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 4.5 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.35.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.35.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.35.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.2 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.35.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.0 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.56b0-py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 13.3 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.5 MB/s eta 0:00:00
# Downloading pybase64-1.4.2-cp311-cp311-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 4.8 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 28.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 92.1 MB/s eta 0:00:00
# Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 26.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.6 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.1 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=355e0a1d4089ac214e1d98f7f2f761bf7cdb62b2500c33e0d89ff715c7eb6fbb
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, durationpy, uvloop, python-dotenv, pybase64, overrides, opentelemetry-proto, mmh3, humanfriendly, httptools, bcrypt, backoff, watchfiles, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, opentelemetry-semantic-conventions, onnxruntime, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
# Successfully installed backoff-2.2.1 bcrypt-4.3.0 chromadb-1.0.15 coloredlogs-15.0.1 durationpy-0.10 httptools-0.6.4 humanfriendly-10.0 kubernetes-33.1.0 mmh3-5.1.0 onnxruntime-1.22.1 opentelemetry-api-1.35.0 opentelemetry-exporter-otlp-proto-common-1.35.0 opentelemetry-exporter-otlp-proto-grpc-1.35.0 opentelemetry-proto-1.35.0 opentelemetry-sdk-1.35.0 opentelemetry-semantic-conventions-0.56b0 overrides-7.7.0 posthog-5.4.0 pybase64-1.4.2 pypika-0.48.9 python-dotenv-1.1.1 uvloop-0.21.0 watchfiles-1.1.0

# %%
# !pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.11/dist-packages (1.27.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from google-genai) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.97.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %%
# !pip install cohere
# Out:
# Collecting cohere
#   Downloading cohere-5.16.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.11/dist-packages (from cohere) (0.28.1)
# Collecting httpx-sse==0.4.0 (from cohere)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from cohere) (2.11.7)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.11/dist-packages (from cohere) (2.33.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.11/dist-packages (from cohere) (0.21.2)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere)
#   Downloading types_requests-2.32.4.20250611-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from cohere) (4.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.21.2->cohere) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.21.2->cohere) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.21.2->cohere) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->cohere) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers<1,>=0.15->cohere) (0.33.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (1.1.5)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.3.1)
# Downloading cohere-5.16.1-py3-none-any.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.9/291.9 kB 5.1 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading fastavro-1.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 41.7 MB/s eta 0:00:00
# Downloading types_requests-2.32.4.20250611-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests, httpx-sse, fastavro, cohere
# Successfully installed cohere-5.16.1 fastavro-1.11.1 httpx-sse-0.4.0 types-requests-2.32.4.20250611

# %%
# !pip install mistralai
# Out:
# Collecting mistralai
#   Downloading mistralai-1.9.3-py3-none-any.whl.metadata (37 kB)
# Collecting eval-type-backport>=0.2.0 (from mistralai)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from mistralai) (0.28.1)
# Requirement already satisfied: pydantic>=2.10.3 in /usr/local/lib/python3.11/dist-packages (from mistralai) (2.11.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from mistralai) (2.9.0.post0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mistralai) (0.4.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.28.1->mistralai) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.28.1->mistralai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.28.1->mistralai) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.28.1->mistralai) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.28.1->mistralai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.10.3->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.10.3->mistralai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.10.3->mistralai) (4.14.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->mistralai) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.28.1->mistralai) (1.3.1)
# Downloading mistralai-1.9.3-py3-none-any.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.3/426.3 kB 9.1 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Installing collected packages: eval-type-backport, mistralai
# Successfully installed eval-type-backport-0.2.2 mistralai-1.9.3

# %% [markdown]
# ## 1. Load and Preprocess

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb
import requests
import os
import json
from google import genai
import openai
from openai import OpenAI
from mistralai import Mistral
import cohere
from pydantic import BaseModel, Field
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
file_path = '/content/stock_news.json'

with open(file_path, 'r') as f:
    stock_data = json.load(f)


all_records = []
for company, news_list in stock_data.items():
    for news_item in news_list:
        news_item['company'] = company  # Add company name to each record
        all_records.append(news_item)

stock_news_df = pd.DataFrame(all_records)
stock_news_df
# Out:
#                                                  title  \
# 0    Apple Inc. (AAPL) Teases New Product Launch wi...
# 1    Apple's Launch of iPhone SE4 Not Seen Impactin...
# 2    Apple Supplier Foxconn's Efforts To Make iPhon...
# 3    Is Apple Inc. (AAPL) the Most Profitable Tech ...
# 4    Apple Partners With Alibaba, Eyes Baidu for AI...
# ..                                                 ...
# 133  Corelight Cuts SIEM Ingest By Up to 80% withou...
# 134  The Zacks Analyst Blog Highlights Apple, Eli L...
# 135  Putting People First Drives Higher Adoption of...
# 136  Cohesity Appoints Carol Carpenter as Chief Mar...
# 137  Rashida Hodge of Microsoft and Gerben Bakker o...
#
#                                                   link ticker  \
# 0    https://finance.yahoo.com/news/apple-inc-aapl-...   AAPL
# 1    https://finance.yahoo.com/news/apple-apos-laun...   AAPL
# 2    https://finance.yahoo.com/news/apple-supplier-...   AAPL
# 3    https://finance.yahoo.com/news/apple-inc-aapl-...   AAPL
# 4    https://finance.yahoo.com/news/apple-partners-...   AAPL
# ..                                                 ...    ...
# 133  https://finance.yahoo.com/news/corelight-cuts-...    IBM
# 134  https://finance.yahoo.com/news/zacks-analyst-b...    IBM
# 135  https://finance.yahoo.com/news/putting-people-...    IBM
# 136  https://finance.yahoo.com/news/cohesity-appoin...    IBM
# 137  https://finance.yahoo.com/news/rashida-hodge-m...    IBM
#
#                                              full_text company
# 0    We recently compiled a list of the 10 High-Fly...    AAPL
# 1    Apple (AAPL)'s launch of the fourth generation...    AAPL
# 2    Apple Supplier Foxconn's Efforts To Make iPhon...    AAPL
# 3    We recently published a list of 10 Most Profit...    AAPL
# 4    Apple (AAPL, Financials) partnered with Alibab...    AAPL
# ..                                                 ...     ...
# 133  New data aggregation capability delivers neede...     IBM
# 134  For Immediate Release Chicago, IL – February 1...     IBM
# 135  Accelerating development of new tools in archi...     IBM
# 136  Carol Carpenter, Chief Marketing Officer, Cohe...     IBM
# 137  MILWAUKEE, Feb. 18, 2025 /PRNewswire/ -- Regal...     IBM
#
# [138 rows x 5 columns]

# %%
# Sanity check if ticker and company are same for all records
stock_news_df.query('ticker == company').shape
# Out:
# (138, 5)

# %%
# Check for null values
print("Null values per column:")
print(stock_news_df.isnull().sum())

# Check for blank strings in columns
print("\nNumber of blank strings in each column:")
for column in stock_news_df.columns:
    num_blanks = (stock_news_df[column].astype(str).str.strip() == '').sum()
    print(f"{column}: {num_blanks}")
# Out:
# Null values per column:
# title        0
# link         0
# ticker       0
# full_text    0
# company      0
# dtype: int64
#
# Number of blank strings in each column:
# title: 0
# link: 0
# ticker: 0
# full_text: 0
# company: 0

# %%
# Create rich document representations with news descriptions
def create_news_documents(stock_news_df):
    """Create rich document representations of news."""
    documents = []

    for idx, news in stock_news_df.iterrows():
        company = news['company']
        title = news['title']
        full_text = news['full_text']
        link = news['link']


        # Create document text - this will be embedded
        doc = f"company: {company}\n"
        if title:
            doc += f"title: {title}\n"
        if full_text:
            doc += f"full_text: {full_text}\n"
        if link:
            doc += f"link: {link}\n"

        documents.append({
            'id': str(idx),
            'content': doc,
            'metadata': {
                'title': title,
                'full_text': full_text,
                'link': link,
                'company': company
            }
        })

    return documents

# Create our document collection
news_documents = create_news_documents(stock_news_df)
print(f"Created {len(news_documents)} news documents")
print(f"Sample document:")
print(news_documents[1]['content'])
# Out:
# Created 138 news documents
# Sample document:
# company: AAPL
# title: Apple's Launch of iPhone SE4 Not Seen Impacting Revenue Guidance, UBS Says
# full_text: Apple (AAPL)'s launch of the fourth generation of the iPhone SE this week has most likely been taken PREMIUM Upgrade to read this MT Newswires article and get so much more. A Silver or Gold subscription plan is required to access premium news articles. Upgrade Already have a subscription? Sign in
# link: https://finance.yahoo.com/news/apple-apos-launch-iphone-se4-152218076.html

# %% [markdown]
# ## 3. Create our Embeddings

# %%
# Initialize embedding model
# Using a smaller model for speed, but can use more powerful ones
model = SentenceTransformer('all-mpnet-base-v2')

# Initialize ChromaDB
chroma_client = chromadb.Client()
collection = chroma_client.create_collection(name="my_news_index")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# chroma_client.delete_collection(name="my_news_index")

# %%
# news_documents[0]

# %%
# Process in batches to avoid memory issues
batch_size = 1000
for i in range(0, len(news_documents), batch_size):
    batch = news_documents[i:i+batch_size]

    ids = [doc['id'] for doc in batch]
    contents = [doc['content'] for doc in batch]
    metadatas = [doc['metadata'] for doc in batch]

    # Generate embeddings
    embeddings = model.encode(contents)

    # Add to collection
    collection.add(
        ids=ids,
        embeddings=embeddings.tolist(),
        documents=contents,
        metadatas=metadatas
    )

print(f"Added {collection.count()} news to the vector database")
# Out:
# Added 138 news to the vector database

# %%
print("\nTest  vector store with a sample query...")
test_query = "how is apple stock performing"

test_embedding = model.encode(test_query).tolist()

results = collection.query(query_embeddings=[test_embedding], n_results=3)

for i, (doc, metadata) in enumerate(zip(results['documents'][0], results['metadatas'][0])):
    print(f"\nResult {i+1}:")
    print(f"title: {metadata['title']}")
    print(f"full_text: {metadata['full_text']}")
    print(f"link: {metadata['link']}")
# Out:
# Test  vector store with a sample query...
#
# Result 1:
# title: Is Apple Inc. (AAPL) the Most Profitable Tech Stock to Buy Now?
# full_text: We recently published a list of 10 Most Profitable Tech Stocks to Buy Now. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other most profitable tech stocks to buy now. Profitability remains one of the most sought-after traits in the technology sector, yet it is also one of the most complex. It is shaped by a delicate balance of investment cycles, competition, and market perception. While topline growth often takes center stage—driving valuations and attracting top talent—sustained profitability becomes crucial as industries mature, competition peaks, and new investments become necessary for survival. In this ever-evolving landscape, technology companies have mastered the art of balancing revenue expansion with profit growth by diversifying their businesses, building vast customer ecosystems, and continuously enhancing product experiences. Looking ahead, earnings growth will take on an even greater role in determining valuations, particularly as the breakneck pace of growth begins to slow. Investors will increasingly focus on sustainable profitability rather than just rapid growth. In a January 2024 article, Rob Haworth, Senior Investment Strategy Director at U.S. Bank Asset Management, emphasized that technology companies possess strong earnings growth potential, largely independent of traditional business cycles. He explained: “What is not clear yet is how companies investing in AI as a way to increase efficiencies or monetize services for end users will benefit from these advancements. We’re in a consolidation phase to figure out what revenue growth will be going forward. If AI helps boost productivity, that will support not only current rising stock valuations but individual prosperity as well.” Franklin Templeton’s 2025 Technology Outlook echoes this sentiment, predicting another year of strong growth in the sector. The report notes that the “Magnificent Seven”—a group of leading tech giants—delivered exceptional earnings in 2024, outpacing both the broader market and the tech industry itself. While these companies are expected to maintain strong momentum, The firm anticipates that the rest of the sector may start catching up in 2025. Tech investments are projected to grow exponentially in the coming years, reshaping the profitability landscape. Emerging technologies such as artificial intelligence, quantum computing, and autonomous systems present both immense opportunities and significant challenges. Some companies will achieve sustainable profit margins through strategic pricing and ecosystem advantages, while others will struggle under the weight of fierce competition and heavy reinvestment costs. For investors and stakeholders, understanding these shifting dynamics is key to navigating the ever-changing tech sector. Story Continues Our Methodology To identify the 10 most profitable stocks, we conducted extensive research on U.S.-listed technology and tech-adjacent companies with a market capitalization of at least $2 billion. Rather than relying solely on absolute net income, we refined our selection criteria by focusing on companies with both an operating margin and net profit margin exceeding 20%. This approach ensures that high-margin firms are not overshadowed by larger corporations with higher overall earnings. After applying these filters, we ranked the stocks in ascending order based on their trailing twelve-month net income, with the company reporting the highest net income securing the top position. Note: All pricing data is as of market close on February 14. At Insider Monkey we are obsessed with the stocks that hedge funds pile into. The reason is simple: our research has shown that we can outperform the market by imitating the top stock picks of the best hedge funds. Our quarterly newsletter’s strategy selects 14 small-cap and large-cap stocks every quarter and has returned 275% since May 2014, beating its benchmark by 150 percentage points (see mor ...
# link: https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
#
# Result 2:
# title: The Zacks Analyst Blog Highlights Apple, Eli Lilly, Shopify and ImmuCell
# full_text: For Immediate Release Chicago, IL – February 18, 2025 – Zacks.com announces the list of stocks featured in the Analyst Blog. Every day the Zacks Equity Research analysts discuss the latest news and events impacting stocks and the financial markets. Stocks recently featured in the blog include: Apple Inc. AAPL, Eli Lilly and Co. LLY, Shopify Inc. SHOP, and ImmuCell Corp. ICCC. Here are highlights from Friday’s Analyst Blog: Top Research Reports for Apple, Eli Lilly and Shopify The Zacks Research Daily presents the best research output of our analyst team. Today's Research Daily features new research reports on 16 major stocks, including Apple Inc., Eli Lilly and Co. and Shopify Inc., as well as a micro-cap stock ImmuCell Corp.. The Zacks microcap research is unique as our research content on these small and under-the-radar companies is the only research of its type in the country.These research reports have been hand-picked from the roughly 70 reports published by our analyst team today.You can see all of today's research reports here >>>Ahead of Wall StreetThe daily 'Ahead of Wall Street' article is a must-read for all investors who would like to be ready for that day's trading action. The article comes out before the market opens and attempts to make sense of that morning's economic releases and how they will affect that day's market action. You can read this article for free on our home page and can actually sign up there to get an email notification as this article comes out each morning.You can read today's AWS here >>> Will Stock Market "Animal Spirits" Continue Thru Valentine's Day? Today's Featured Research ReportsShares of Apple have gained +27.1% over the past year against the Zacks Computer - Micro Computers industry's gain of +31.9%. The company is benefiting from strong growth in Services revenues. It now has more than 1 billion paid subscribers across its Services portfolio, more than double what it had four years ago.The expanding content portfolio of Apple TV+ and Apple Arcade helped in driving subscriber growth. Apple expects the March quarter's (second-quarter fiscal 2025) revenues to grow low to mid-single digits on a year-over-year basis. For the Services segment, It expects a low double-digit growth rate.Introduction of Apple Intelligence, an advanced personal intelligence system seamlessly integrated into iOS 18, iPadOS 18 and macOS Sequoia will help Apple shares to push higher. However, weakness in iPhone sales particularly in China is a concern. Increasing regulatory headwinds is a headwind.(You can read the full research report on Apple here >>>)Eli Lilly's shares have outperformed the Zacks Large Cap Pharmaceuticals industry over the past year (+14.7% vs. +2.9%). The company's Q4 earnings beat estimates while sales missed the same. Demand for Lilly's popular GLP-1 drugs, Mounjaro and Zepbound, remains strong, making them the company's key top-line drivers.In the past two years, Lilly has received approvals for several new drugs like Kisunla, Omvoh and Jaypirca. Its new drugs contributed significantly to its top-line growth in 2024. Lilly is also making rapid pipeline progress in areas like obesity, diabetes and Alzheimer's.However, sales of Mounjaro/Zepbound were disappointing in the second half of 2024 due to slower-than-expected growth, which has raised concerns about moderating demand for the drugs. Declining sales of Trulicity and potential competition in the GLP-1 diabetes/obesity market are some top-line headwinds.(You can read the full research report on Eli Lilly here >>>)Shares of Shopify have outperformed the Zacks Internet - Services industry over the past year (+47.1% vs. +28%). The company is benefiting from strong growth in its merchant base. New merchant-friendly tools like Shopify Balance, Shopify Tax, Shopify Inbox and Tap to Pay solutions are helping it to win new merchants regularly.Strong adoption of these solutions holds promise for Shopify's prospects. Integration of Sh ...
# link: https://finance.yahoo.com/news/zacks-analyst-blog-highlights-apple-144800950.html
#
# Result 3:
# title: Wall Street bullish as cash levels drop to 15-year low: BofA
# full_text: Wall Street is feeling bullish as Bank of America's global fund manager survey pointing to cash levels having fallen to a 15-year low. Yahoo Finance Senior Reporter Josh Schafer joins Morning Brief to discuss the latest Bank of America survey, highlighting that fund managers are moving away from the crowded Magnificent Seven trade — the group of tech stocks comprised of Alphabet (GOOG, GOOGL), Apple (AAPL), Nvidia (NVDA), Tesla (TSLA), Amazon (AMZN), Meta Platforms (META), and Microsoft (MSFT). Instead, managers are now more focused on global equities, gold (GC=F), and small-cap US stocks. This shift could lead to a stock picker’s market with potential risks tied to market leadership and the Federal Reserve's stance on interest rates. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here. This post was written by Josh Lynch Related Videos 02:34 Growing bearish sentiments is actually bullish? Here's why. Yahoo Finance Video • 26 minutes ago 00:57 Conagra, Robinhood, Meta all slip: Market Minute Yahoo Finance Video • 30 minutes ago 00:57 Amazon Inspire, Super Micro soars, Fluor: Market Minute Yahoo Finance Video • 55 minutes ago 43:53 Homebuyer advice and mistakes, budgeting strategies for you: Wealth Yahoo Finance Video • 1 hour ago View Comments
# link: https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html

# %%
results
# Out:
# {'ids': [['3', '9', '7']],
#  'embeddings': None,
#  'documents': [['company: AAPL\ntitle: Is Apple Inc. (AAPL) the Most Profitable Tech Stock to Buy Now?\nfull_text: We recently published a list of 10 Most Profitable Tech Stocks to Buy Now. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other most profitable tech stocks to buy now. Profitability remains one of the most sought-after traits in the technology sector, yet it is also one of the most complex. It is shaped by a delicate balance of investment cycles, competition, and market perception. While topline growth often takes center stage—driving valuations and attracting top talent—sustained profitability becomes crucial as industries mature, competition peaks, and new investments become necessary for survival. In this ever-evolving landscape, technology companies have mastered the art of balancing revenue expansion with profit growth by diversifying their businesses, building vast customer ecosystems, and continuously enhancing product experiences. Looking ahead, earnings growth will take on an even greater role in determining valuations, particularly as the breakneck pace of growth begins to slow. Investors will increasingly focus on sustainable profitability rather than just rapid growth. In a January 2024 article, Rob Haworth, Senior Investment Strategy Director at U.S. Bank Asset Management, emphasized that technology companies possess strong earnings growth potential, largely independent of traditional business cycles. He explained: “What is not clear yet is how companies investing in AI as a way to increase efficiencies or monetize services for end users will benefit from these advancements. We’re in a consolidation phase to figure out what revenue growth will be going forward. If AI helps boost productivity, that will support not only current rising stock valuations but individual prosperity as well.” Franklin Templeton’s 2025 Technology Outlook echoes this sentiment, predicting another year of strong growth in the sector. The report notes that the “Magnificent Seven”—a group of leading tech giants—delivered exceptional earnings in 2024, outpacing both the broader market and the tech industry itself. While these companies are expected to maintain strong momentum, The firm anticipates that the rest of the sector may start catching up in 2025. Tech investments are projected to grow exponentially in the coming years, reshaping the profitability landscape. Emerging technologies such as artificial intelligence, quantum computing, and autonomous systems present both immense opportunities and significant challenges. Some companies will achieve sustainable profit margins through strategic pricing and ecosystem advantages, while others will struggle under the weight of fierce competition and heavy reinvestment costs. For investors and stakeholders, understanding these shifting dynamics is key to navigating the ever-changing tech sector. Story Continues Our Methodology To identify the 10 most profitable stocks, we conducted extensive research on U.S.-listed technology and tech-adjacent companies with a market capitalization of at least $2 billion. Rather than relying solely on absolute net income, we refined our selection criteria by focusing on companies with both an operating margin and net profit margin exceeding 20%. This approach ensures that high-margin firms are not overshadowed by larger corporations with higher overall earnings. After applying these filters, we ranked the stocks in ascending order based on their trailing twelve-month net income, with the company reporting the highest net income securing the top position. Note: All pricing data is as of market close on February 14. At Insider Monkey we are obsessed with the stocks that hedge funds pile into. The reason is simple: our research has shown that we can outperform the market by imitating the top stock picks of the best hedge funds. Our quarterly newsletter’s strategy selects 14 small-cap and large-cap stocks eve ...
#    'company: AAPL\ntitle: The Zacks Analyst Blog Highlights Apple, Eli Lilly, Shopify and ImmuCell\nfull_text: For Immediate Release Chicago, IL – February 18, 2025 – Zacks.com announces the list of stocks featured in the Analyst Blog. Every day the Zacks Equity Research analysts discuss the latest news and events impacting stocks and the financial markets. Stocks recently featured in the blog include: Apple Inc. AAPL, Eli Lilly and Co. LLY, Shopify Inc. SHOP, and ImmuCell Corp. ICCC. Here are highlights from Friday’s Analyst Blog: Top Research Reports for Apple, Eli Lilly and Shopify The Zacks Research Daily presents the best research output of our analyst team. Today\'s Research Daily features new research reports on 16 major stocks, including Apple Inc., Eli Lilly and Co. and Shopify Inc., as well as a micro-cap stock ImmuCell Corp.. The Zacks microcap research is unique as our research content on these small and under-the-radar companies is the only research of its type in the country.These research reports have been hand-picked from the roughly 70 reports published by our analyst team today.You can see all of today\'s research reports here >>>Ahead of Wall StreetThe daily \'Ahead of Wall Street\' article is a must-read for all investors who would like to be ready for that day\'s trading action. The article comes out before the market opens and attempts to make sense of that morning\'s economic releases and how they will affect that day\'s market action. You can read this article for free on our home page and can actually sign up there to get an email notification as this article comes out each morning.You can read today\'s AWS here >>> Will Stock Market "Animal Spirits" Continue Thru Valentine\'s Day? Today\'s Featured Research ReportsShares of Apple have gained +27.1% over the past year against the Zacks Computer - Micro Computers industry\'s gain of +31.9%. The company is benefiting from strong growth in Services revenues. It now has more than 1 billion paid subscribers across its Services portfolio, more than double what it had four years ago.The expanding content portfolio of Apple TV+ and Apple Arcade helped in driving subscriber growth. Apple expects the March quarter\'s (second-quarter fiscal 2025) revenues to grow low to mid-single digits on a year-over-year basis. For the Services segment, It expects a low double-digit growth rate.Introduction of Apple Intelligence, an advanced personal intelligence system seamlessly integrated into iOS 18, iPadOS 18 and macOS Sequoia will help Apple shares to push higher. However, weakness in iPhone sales particularly in China is a concern. Increasing regulatory headwinds is a headwind.(You can read the full research report on Apple here >>>)Eli Lilly\'s shares have outperformed the Zacks Large Cap Pharmaceuticals industry over the past year (+14.7% vs. +2.9%). The company\'s Q4 earnings beat estimates while sales missed the same. Demand for Lilly\'s popular GLP-1 drugs, Mounjaro and Zepbound, remains strong, making them the company\'s key top-line drivers.In the past two years, Lilly has received approvals for several new drugs like Kisunla, Omvoh and Jaypirca. Its new drugs contributed significantly to its top-line growth in 2024. Lilly is also making rapid pipeline progress in areas like obesity, diabetes and Alzheimer\'s.However, sales of Mounjaro/Zepbound were disappointing in the second half of 2024 due to slower-than-expected growth, which has raised concerns about moderating demand for the drugs. Declining sales of Trulicity and potential competition in the GLP-1 diabetes/obesity market are some top-line headwinds.(You can read the full research report on Eli Lilly here >>>)Shares of Shopify have outperformed the Zacks Internet - Services industry over the past year (+47.1% vs. +28%). The company is benefiting from strong growth in its merchant base. New merchant-friendly tools like Shopify Balance, Shopify Tax, Shopify Inbox and Tap to Pay solutions are helping it to wi ...
#    "company: AAPL\ntitle: Wall Street bullish as cash levels drop to 15-year low: BofA\nfull_text: Wall Street is feeling bullish as Bank of America's global fund manager survey pointing to cash levels having fallen to a 15-year low. Yahoo Finance Senior Reporter Josh Schafer joins Morning Brief to discuss the latest Bank of America survey, highlighting that fund managers are moving away from the crowded Magnificent Seven trade — the group of tech stocks comprised of Alphabet (GOOG, GOOGL), Apple (AAPL), Nvidia (NVDA), Tesla (TSLA), Amazon (AMZN), Meta Platforms (META), and Microsoft (MSFT). Instead, managers are now more focused on global equities, gold (GC=F), and small-cap US stocks. This shift could lead to a stock picker’s market with potential risks tied to market leadership and the Federal Reserve's stance on interest rates. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here. This post was written by Josh Lynch Related Videos 02:34 Growing bearish sentiments is actually bullish? Here's why. Yahoo Finance Video • 26 minutes ago 00:57 Conagra, Robinhood, Meta all slip: Market Minute Yahoo Finance Video • 30 minutes ago 00:57 Amazon Inspire, Super Micro soars, Fluor: Market Minute Yahoo Finance Video • 55 minutes ago 43:53 Homebuyer advice and mistakes, budgeting strategies for you: Wealth Yahoo Finance Video • 1 hour ago View Comments\nlink: https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html\n"]],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'link': 'https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html',
#     'company': 'AAPL',
#     'full_text': 'We recently published a list of 10 Most Profitable Tech Stocks to Buy Now. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other most profitable tech stocks to buy now. Profitability remains one of the most sought-after traits in the technology sector, yet it is also one of the most complex. It is shaped by a delicate balance of investment cycles, competition, and market perception. While topline growth often takes center stage—driving valuations and attracting top talent—sustained profitability becomes crucial as industries mature, competition peaks, and new investments become necessary for survival. In this ever-evolving landscape, technology companies have mastered the art of balancing revenue expansion with profit growth by diversifying their businesses, building vast customer ecosystems, and continuously enhancing product experiences. Looking ahead, earnings growth will take on an even greater role in determining valuations, particularly as the breakneck pace of growth begins to slow. Investors will increasingly focus on sustainable profitability rather than just rapid growth. In a January 2024 article, Rob Haworth, Senior Investment Strategy Director at U.S. Bank Asset Management, emphasized that technology companies possess strong earnings growth potential, largely independent of traditional business cycles. He explained: “What is not clear yet is how companies investing in AI as a way to increase efficiencies or monetize services for end users will benefit from these advancements. We’re in a consolidation phase to figure out what revenue growth will be going forward. If AI helps boost productivity, that will support not only current rising stock valuations but individual prosperity as well.” Franklin Templeton’s 2025 Technology Outlook echoes this sentiment, predicting another year of strong growth in the sector. The report notes that the “Magnificent Seven”—a group of leading tech giants—delivered exceptional earnings in 2024, outpacing both the broader market and the tech industry itself. While these companies are expected to maintain strong momentum, The firm anticipates that the rest of the sector may start catching up in 2025. Tech investments are projected to grow exponentially in the coming years, reshaping the profitability landscape. Emerging technologies such as artificial intelligence, quantum computing, and autonomous systems present both immense opportunities and significant challenges. Some companies will achieve sustainable profit margins through strategic pricing and ecosystem advantages, while others will struggle under the weight of fierce competition and heavy reinvestment costs. For investors and stakeholders, understanding these shifting dynamics is key to navigating the ever-changing tech sector. Story Continues Our Methodology To identify the 10 most profitable stocks, we conducted extensive research on U.S.-listed technology and tech-adjacent companies with a market capitalization of at least $2 billion. Rather than relying solely on absolute net income, we refined our selection criteria by focusing on companies with both an operating margin and net profit margin exceeding 20%. This approach ensures that high-margin firms are not overshadowed by larger corporations with higher overall earnings. After applying these filters, we ranked the stocks in ascending order based on their trailing twelve-month net income, with the company reporting the highest net income securing the top position. Note: All pricing data is as of market close on February 14. At Insider Monkey we are obsessed with the stocks that hedge funds pile into. The reason is simple: our research has shown that we can outperform the market by imitating the top stock picks of the best hedge funds. Our quarterly newsletter’s strategy selects 14 small-cap and large-cap stocks every quarter and has returned 275% since May 2014, beating its benchmark by 150 percentage points\x ...
#     'title': 'Is Apple Inc. (AAPL) the Most Profitable Tech Stock to Buy Now?'},
#    {'full_text': 'For Immediate Release Chicago, IL – February 18, 2025 – Zacks.com announces the list of stocks featured in the Analyst Blog. Every day the Zacks Equity Research analysts discuss the latest news and events impacting stocks and the financial markets. Stocks recently featured in the blog include: Apple Inc. AAPL, Eli Lilly and Co. LLY, Shopify Inc. SHOP, and ImmuCell Corp. ICCC. Here are highlights from Friday’s Analyst Blog: Top Research Reports for Apple, Eli Lilly and Shopify The Zacks Research Daily presents the best research output of our analyst team. Today\'s Research Daily features new research reports on 16 major stocks, including Apple Inc., Eli Lilly and Co. and Shopify Inc., as well as a micro-cap stock ImmuCell Corp.. The Zacks microcap research is unique as our research content on these small and under-the-radar companies is the only research of its type in the country.These research reports have been hand-picked from the roughly 70 reports published by our analyst team today.You can see all of today\'s research reports here >>>Ahead of Wall StreetThe daily \'Ahead of Wall Street\' article is a must-read for all investors who would like to be ready for that day\'s trading action. The article comes out before the market opens and attempts to make sense of that morning\'s economic releases and how they will affect that day\'s market action. You can read this article for free on our home page and can actually sign up there to get an email notification as this article comes out each morning.You can read today\'s AWS here >>> Will Stock Market "Animal Spirits" Continue Thru Valentine\'s Day? Today\'s Featured Research ReportsShares of Apple have gained +27.1% over the past year against the Zacks Computer - Micro Computers industry\'s gain of +31.9%. The company is benefiting from strong growth in Services revenues. It now has more than 1 billion paid subscribers across its Services portfolio, more than double what it had four years ago.The expanding content portfolio of Apple TV+ and Apple Arcade helped in driving subscriber growth. Apple expects the March quarter\'s (second-quarter fiscal 2025) revenues to grow low to mid-single digits on a year-over-year basis. For the Services segment, It expects a low double-digit growth rate.Introduction of Apple Intelligence, an advanced personal intelligence system seamlessly integrated into iOS 18, iPadOS 18 and macOS Sequoia will help Apple shares to push higher. However, weakness in iPhone sales particularly in China is a concern. Increasing regulatory headwinds is a headwind.(You can read the full research report on Apple here >>>)Eli Lilly\'s shares have outperformed the Zacks Large Cap Pharmaceuticals industry over the past year (+14.7% vs. +2.9%). The company\'s Q4 earnings beat estimates while sales missed the same. Demand for Lilly\'s popular GLP-1 drugs, Mounjaro and Zepbound, remains strong, making them the company\'s key top-line drivers.In the past two years, Lilly has received approvals for several new drugs like Kisunla, Omvoh and Jaypirca. Its new drugs contributed significantly to its top-line growth in 2024. Lilly is also making rapid pipeline progress in areas like obesity, diabetes and Alzheimer\'s.However, sales of Mounjaro/Zepbound were disappointing in the second half of 2024 due to slower-than-expected growth, which has raised concerns about moderating demand for the drugs. Declining sales of Trulicity and potential competition in the GLP-1 diabetes/obesity market are some top-line headwinds.(You can read the full research report on Eli Lilly here >>>)Shares of Shopify have outperformed the Zacks Internet - Services industry over the past year (+47.1% vs. +28%). The company is benefiting from strong growth in its merchant base. New merchant-friendly tools like Shopify Balance, Shopify Tax, Shopify Inbox and Tap to Pay solutions are helping it to win new merchants regularly.Strong adoption of these solutions holds promise for Shopify\'s pro ...
#     'link': 'https://finance.yahoo.com/news/zacks-analyst-blog-highlights-apple-144800950.html',
#     'title': 'The Zacks Analyst Blog Highlights Apple, Eli Lilly, Shopify and ImmuCell',
#     'company': 'AAPL'},
#    {'full_text': "Wall Street is feeling bullish as Bank of America's global fund manager survey pointing to cash levels having fallen to a 15-year low. Yahoo Finance Senior Reporter Josh Schafer joins Morning Brief to discuss the latest Bank of America survey, highlighting that fund managers are moving away from the crowded Magnificent Seven trade — the group of tech stocks comprised of Alphabet (GOOG, GOOGL), Apple (AAPL), Nvidia (NVDA), Tesla (TSLA), Amazon (AMZN), Meta Platforms (META), and Microsoft (MSFT). Instead, managers are now more focused on global equities, gold (GC=F), and small-cap US stocks. This shift could lead to a stock picker’s market with potential risks tied to market leadership and the Federal Reserve's stance on interest rates. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here. This post was written by Josh Lynch Related Videos 02:34 Growing bearish sentiments is actually bullish? Here's why. Yahoo Finance Video • 26 minutes ago 00:57 Conagra, Robinhood, Meta all slip: Market Minute Yahoo Finance Video • 30 minutes ago 00:57 Amazon Inspire, Super Micro soars, Fluor: Market Minute Yahoo Finance Video • 55 minutes ago 43:53 Homebuyer advice and mistakes, budgeting strategies for you: Wealth Yahoo Finance Video • 1 hour ago View Comments",
#     'company': 'AAPL',
#     'title': 'Wall Street bullish as cash levels drop to 15-year low: BofA',
#     'link': 'https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html'}]],
#  'distances': [[0.8348534107208252, 0.844607949256897, 0.8470443487167358]]}

# %% [markdown]
# ## 4. Create Retrieval

# %% [markdown]
# ### 4.1 Basic Retrieval

# %%
def query_expansion(query):
    """Expand the query for better retrieval of financial news."""
    # Simple rule-based expansions
    expansions = [
        query, # Original query
        f"Latest news about {query}",
        f"{query} stock news",
        f"{query} financial performance",
        f"{query} market impact",
    ]
    return expansions

def retrieve_news_info(query, n_results=5):
    """Retrieve relevant news information for a query."""
    # Expand query for better recall
    expanded_queries = query_expansion(query)

    all_results = []
    for expanded_query in expanded_queries:
        # Generate embedding for the query
        query_embedding = model.encode(expanded_query).tolist()

        # Retrieve relevant documents
        results = collection.query(
            query_embeddings=[query_embedding],
            n_results=n_results
        )

        # Add to results list
        for doc, metadata, id in zip(results['documents'][0],
                                    results['metadatas'][0],
                                    results['ids'][0]):
            all_results.append({
                'id': id,
                'document': doc,
                'metadata': metadata,
                'query': expanded_query
            })

    # Remove duplicates (same news link)
    unique_results = {}
    for result in all_results:
        if result['id'] not in unique_results:
            unique_results[result['id']] = result

    return list(unique_results.values())

# %%
retrieve_news_info("how is apple stock performing")
# Out:
# [{'id': '3',
#   'document': 'company: AAPL\ntitle: Is Apple Inc. (AAPL) the Most Profitable Tech Stock to Buy Now?\nfull_text: We recently published a list of 10 Most Profitable Tech Stocks to Buy Now. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other most profitable tech stocks to buy now. Profitability remains one of the most sought-after traits in the technology sector, yet it is also one of the most complex. It is shaped by a delicate balance of investment cycles, competition, and market perception. While topline growth often takes center stage—driving valuations and attracting top talent—sustained profitability becomes crucial as industries mature, competition peaks, and new investments become necessary for survival. In this ever-evolving landscape, technology companies have mastered the art of balancing revenue expansion with profit growth by diversifying their businesses, building vast customer ecosystems, and continuously enhancing product experiences. Looking ahead, earnings growth will take on an even greater role in determining valuations, particularly as the breakneck pace of growth begins to slow. Investors will increasingly focus on sustainable profitability rather than just rapid growth. In a January 2024 article, Rob Haworth, Senior Investment Strategy Director at U.S. Bank Asset Management, emphasized that technology companies possess strong earnings growth potential, largely independent of traditional business cycles. He explained: “What is not clear yet is how companies investing in AI as a way to increase efficiencies or monetize services for end users will benefit from these advancements. We’re in a consolidation phase to figure out what revenue growth will be going forward. If AI helps boost productivity, that will support not only current rising stock valuations but individual prosperity as well.” Franklin Templeton’s 2025 Technology Outlook echoes this sentiment, predicting another year of strong growth in the sector. The report notes that the “Magnificent Seven”—a group of leading tech giants—delivered exceptional earnings in 2024, outpacing both the broader market and the tech industry itself. While these companies are expected to maintain strong momentum, The firm anticipates that the rest of the sector may start catching up in 2025. Tech investments are projected to grow exponentially in the coming years, reshaping the profitability landscape. Emerging technologies such as artificial intelligence, quantum computing, and autonomous systems present both immense opportunities and significant challenges. Some companies will achieve sustainable profit margins through strategic pricing and ecosystem advantages, while others will struggle under the weight of fierce competition and heavy reinvestment costs. For investors and stakeholders, understanding these shifting dynamics is key to navigating the ever-changing tech sector. Story Continues Our Methodology To identify the 10 most profitable stocks, we conducted extensive research on U.S.-listed technology and tech-adjacent companies with a market capitalization of at least $2 billion. Rather than relying solely on absolute net income, we refined our selection criteria by focusing on companies with both an operating margin and net profit margin exceeding 20%. This approach ensures that high-margin firms are not overshadowed by larger corporations with higher overall earnings. After applying these filters, we ranked the stocks in ascending order based on their trailing twelve-month net income, with the company reporting the highest net income securing the top position. Note: All pricing data is as of market close on February 14. At Insider Monkey we are obsessed with the stocks that hedge funds pile into. The reason is simple: our research has shown that we can outperform the market by imitating the top stock picks of the best hedge funds. Our quarterly newsletter’s strategy selects 14 small-cap and large-cap stocks every ...
#   'metadata': {'full_text': 'We recently published a list of 10 Most Profitable Tech Stocks to Buy Now. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other most profitable tech stocks to buy now. Profitability remains one of the most sought-after traits in the technology sector, yet it is also one of the most complex. It is shaped by a delicate balance of investment cycles, competition, and market perception. While topline growth often takes center stage—driving valuations and attracting top talent—sustained profitability becomes crucial as industries mature, competition peaks, and new investments become necessary for survival. In this ever-evolving landscape, technology companies have mastered the art of balancing revenue expansion with profit growth by diversifying their businesses, building vast customer ecosystems, and continuously enhancing product experiences. Looking ahead, earnings growth will take on an even greater role in determining valuations, particularly as the breakneck pace of growth begins to slow. Investors will increasingly focus on sustainable profitability rather than just rapid growth. In a January 2024 article, Rob Haworth, Senior Investment Strategy Director at U.S. Bank Asset Management, emphasized that technology companies possess strong earnings growth potential, largely independent of traditional business cycles. He explained: “What is not clear yet is how companies investing in AI as a way to increase efficiencies or monetize services for end users will benefit from these advancements. We’re in a consolidation phase to figure out what revenue growth will be going forward. If AI helps boost productivity, that will support not only current rising stock valuations but individual prosperity as well.” Franklin Templeton’s 2025 Technology Outlook echoes this sentiment, predicting another year of strong growth in the sector. The report notes that the “Magnificent Seven”—a group of leading tech giants—delivered exceptional earnings in 2024, outpacing both the broader market and the tech industry itself. While these companies are expected to maintain strong momentum, The firm anticipates that the rest of the sector may start catching up in 2025. Tech investments are projected to grow exponentially in the coming years, reshaping the profitability landscape. Emerging technologies such as artificial intelligence, quantum computing, and autonomous systems present both immense opportunities and significant challenges. Some companies will achieve sustainable profit margins through strategic pricing and ecosystem advantages, while others will struggle under the weight of fierce competition and heavy reinvestment costs. For investors and stakeholders, understanding these shifting dynamics is key to navigating the ever-changing tech sector. Story Continues Our Methodology To identify the 10 most profitable stocks, we conducted extensive research on U.S.-listed technology and tech-adjacent companies with a market capitalization of at least $2 billion. Rather than relying solely on absolute net income, we refined our selection criteria by focusing on companies with both an operating margin and net profit margin exceeding 20%. This approach ensures that high-margin firms are not overshadowed by larger corporations with higher overall earnings. After applying these filters, we ranked the stocks in ascending order based on their trailing twelve-month net income, with the company reporting the highest net income securing the top position. Note: All pricing data is as of market close on February 14. At Insider Monkey we are obsessed with the stocks that hedge funds pile into. The reason is simple: our research has shown that we can outperform the market by imitating the top stock picks of the best hedge funds. Our quarterly newsletter’s strategy selects 14 small-cap and large-cap stocks every quarter and has returned 275% since May 2014, beating its benchmark by 150 percenta ...
#    'link': 'https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html',
#    'company': 'AAPL',
#    'title': 'Is Apple Inc. (AAPL) the Most Profitable Tech Stock to Buy Now?'},
#   'query': 'how is apple stock performing'},
#  {'id': '9',
#   'document': 'company: AAPL\ntitle: The Zacks Analyst Blog Highlights Apple, Eli Lilly, Shopify and ImmuCell\nfull_text: For Immediate Release Chicago, IL – February 18, 2025 – Zacks.com announces the list of stocks featured in the Analyst Blog. Every day the Zacks Equity Research analysts discuss the latest news and events impacting stocks and the financial markets. Stocks recently featured in the blog include: Apple Inc. AAPL, Eli Lilly and Co. LLY, Shopify Inc. SHOP, and ImmuCell Corp. ICCC. Here are highlights from Friday’s Analyst Blog: Top Research Reports for Apple, Eli Lilly and Shopify The Zacks Research Daily presents the best research output of our analyst team. Today\'s Research Daily features new research reports on 16 major stocks, including Apple Inc., Eli Lilly and Co. and Shopify Inc., as well as a micro-cap stock ImmuCell Corp.. The Zacks microcap research is unique as our research content on these small and under-the-radar companies is the only research of its type in the country.These research reports have been hand-picked from the roughly 70 reports published by our analyst team today.You can see all of today\'s research reports here >>>Ahead of Wall StreetThe daily \'Ahead of Wall Street\' article is a must-read for all investors who would like to be ready for that day\'s trading action. The article comes out before the market opens and attempts to make sense of that morning\'s economic releases and how they will affect that day\'s market action. You can read this article for free on our home page and can actually sign up there to get an email notification as this article comes out each morning.You can read today\'s AWS here >>> Will Stock Market "Animal Spirits" Continue Thru Valentine\'s Day? Today\'s Featured Research ReportsShares of Apple have gained +27.1% over the past year against the Zacks Computer - Micro Computers industry\'s gain of +31.9%. The company is benefiting from strong growth in Services revenues. It now has more than 1 billion paid subscribers across its Services portfolio, more than double what it had four years ago.The expanding content portfolio of Apple TV+ and Apple Arcade helped in driving subscriber growth. Apple expects the March quarter\'s (second-quarter fiscal 2025) revenues to grow low to mid-single digits on a year-over-year basis. For the Services segment, It expects a low double-digit growth rate.Introduction of Apple Intelligence, an advanced personal intelligence system seamlessly integrated into iOS 18, iPadOS 18 and macOS Sequoia will help Apple shares to push higher. However, weakness in iPhone sales particularly in China is a concern. Increasing regulatory headwinds is a headwind.(You can read the full research report on Apple here >>>)Eli Lilly\'s shares have outperformed the Zacks Large Cap Pharmaceuticals industry over the past year (+14.7% vs. +2.9%). The company\'s Q4 earnings beat estimates while sales missed the same. Demand for Lilly\'s popular GLP-1 drugs, Mounjaro and Zepbound, remains strong, making them the company\'s key top-line drivers.In the past two years, Lilly has received approvals for several new drugs like Kisunla, Omvoh and Jaypirca. Its new drugs contributed significantly to its top-line growth in 2024. Lilly is also making rapid pipeline progress in areas like obesity, diabetes and Alzheimer\'s.However, sales of Mounjaro/Zepbound were disappointing in the second half of 2024 due to slower-than-expected growth, which has raised concerns about moderating demand for the drugs. Declining sales of Trulicity and potential competition in the GLP-1 diabetes/obesity market are some top-line headwinds.(You can read the full research report on Eli Lilly here >>>)Shares of Shopify have outperformed the Zacks Internet - Services industry over the past year (+47.1% vs. +28%). The company is benefiting from strong growth in its merchant base. New merchant-friendly tools like Shopify Balance, Shopify Tax, Shopify Inbox and Tap to Pay solutions are helpi ...
#   'metadata': {'link': 'https://finance.yahoo.com/news/zacks-analyst-blog-highlights-apple-144800950.html',
#    'full_text': 'For Immediate Release Chicago, IL – February 18, 2025 – Zacks.com announces the list of stocks featured in the Analyst Blog. Every day the Zacks Equity Research analysts discuss the latest news and events impacting stocks and the financial markets. Stocks recently featured in the blog include: Apple Inc. AAPL, Eli Lilly and Co. LLY, Shopify Inc. SHOP, and ImmuCell Corp. ICCC. Here are highlights from Friday’s Analyst Blog: Top Research Reports for Apple, Eli Lilly and Shopify The Zacks Research Daily presents the best research output of our analyst team. Today\'s Research Daily features new research reports on 16 major stocks, including Apple Inc., Eli Lilly and Co. and Shopify Inc., as well as a micro-cap stock ImmuCell Corp.. The Zacks microcap research is unique as our research content on these small and under-the-radar companies is the only research of its type in the country.These research reports have been hand-picked from the roughly 70 reports published by our analyst team today.You can see all of today\'s research reports here >>>Ahead of Wall StreetThe daily \'Ahead of Wall Street\' article is a must-read for all investors who would like to be ready for that day\'s trading action. The article comes out before the market opens and attempts to make sense of that morning\'s economic releases and how they will affect that day\'s market action. You can read this article for free on our home page and can actually sign up there to get an email notification as this article comes out each morning.You can read today\'s AWS here >>> Will Stock Market "Animal Spirits" Continue Thru Valentine\'s Day? Today\'s Featured Research ReportsShares of Apple have gained +27.1% over the past year against the Zacks Computer - Micro Computers industry\'s gain of +31.9%. The company is benefiting from strong growth in Services revenues. It now has more than 1 billion paid subscribers across its Services portfolio, more than double what it had four years ago.The expanding content portfolio of Apple TV+ and Apple Arcade helped in driving subscriber growth. Apple expects the March quarter\'s (second-quarter fiscal 2025) revenues to grow low to mid-single digits on a year-over-year basis. For the Services segment, It expects a low double-digit growth rate.Introduction of Apple Intelligence, an advanced personal intelligence system seamlessly integrated into iOS 18, iPadOS 18 and macOS Sequoia will help Apple shares to push higher. However, weakness in iPhone sales particularly in China is a concern. Increasing regulatory headwinds is a headwind.(You can read the full research report on Apple here >>>)Eli Lilly\'s shares have outperformed the Zacks Large Cap Pharmaceuticals industry over the past year (+14.7% vs. +2.9%). The company\'s Q4 earnings beat estimates while sales missed the same. Demand for Lilly\'s popular GLP-1 drugs, Mounjaro and Zepbound, remains strong, making them the company\'s key top-line drivers.In the past two years, Lilly has received approvals for several new drugs like Kisunla, Omvoh and Jaypirca. Its new drugs contributed significantly to its top-line growth in 2024. Lilly is also making rapid pipeline progress in areas like obesity, diabetes and Alzheimer\'s.However, sales of Mounjaro/Zepbound were disappointing in the second half of 2024 due to slower-than-expected growth, which has raised concerns about moderating demand for the drugs. Declining sales of Trulicity and potential competition in the GLP-1 diabetes/obesity market are some top-line headwinds.(You can read the full research report on Eli Lilly here >>>)Shares of Shopify have outperformed the Zacks Internet - Services industry over the past year (+47.1% vs. +28%). The company is benefiting from strong growth in its merchant base. New merchant-friendly tools like Shopify Balance, Shopify Tax, Shopify Inbox and Tap to Pay solutions are helping it to win new merchants regularly.Strong adoption of these solutions holds promise for Shopify\'s pros ...
#    'title': 'The Zacks Analyst Blog Highlights Apple, Eli Lilly, Shopify and ImmuCell',
#    'company': 'AAPL'},
#   'query': 'how is apple stock performing'},
#  {'id': '7',
#   'document': "company: AAPL\ntitle: Wall Street bullish as cash levels drop to 15-year low: BofA\nfull_text: Wall Street is feeling bullish as Bank of America's global fund manager survey pointing to cash levels having fallen to a 15-year low. Yahoo Finance Senior Reporter Josh Schafer joins Morning Brief to discuss the latest Bank of America survey, highlighting that fund managers are moving away from the crowded Magnificent Seven trade — the group of tech stocks comprised of Alphabet (GOOG, GOOGL), Apple (AAPL), Nvidia (NVDA), Tesla (TSLA), Amazon (AMZN), Meta Platforms (META), and Microsoft (MSFT). Instead, managers are now more focused on global equities, gold (GC=F), and small-cap US stocks. This shift could lead to a stock picker’s market with potential risks tied to market leadership and the Federal Reserve's stance on interest rates. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here. This post was written by Josh Lynch Related Videos 02:34 Growing bearish sentiments is actually bullish? Here's why. Yahoo Finance Video • 26 minutes ago 00:57 Conagra, Robinhood, Meta all slip: Market Minute Yahoo Finance Video • 30 minutes ago 00:57 Amazon Inspire, Super Micro soars, Fluor: Market Minute Yahoo Finance Video • 55 minutes ago 43:53 Homebuyer advice and mistakes, budgeting strategies for you: Wealth Yahoo Finance Video • 1 hour ago View Comments\nlink: https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html\n",
#   'metadata': {'title': 'Wall Street bullish as cash levels drop to 15-year low: BofA',
#    'full_text': "Wall Street is feeling bullish as Bank of America's global fund manager survey pointing to cash levels having fallen to a 15-year low. Yahoo Finance Senior Reporter Josh Schafer joins Morning Brief to discuss the latest Bank of America survey, highlighting that fund managers are moving away from the crowded Magnificent Seven trade — the group of tech stocks comprised of Alphabet (GOOG, GOOGL), Apple (AAPL), Nvidia (NVDA), Tesla (TSLA), Amazon (AMZN), Meta Platforms (META), and Microsoft (MSFT). Instead, managers are now more focused on global equities, gold (GC=F), and small-cap US stocks. This shift could lead to a stock picker’s market with potential risks tied to market leadership and the Federal Reserve's stance on interest rates. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here. This post was written by Josh Lynch Related Videos 02:34 Growing bearish sentiments is actually bullish? Here's why. Yahoo Finance Video • 26 minutes ago 00:57 Conagra, Robinhood, Meta all slip: Market Minute Yahoo Finance Video • 30 minutes ago 00:57 Amazon Inspire, Super Micro soars, Fluor: Market Minute Yahoo Finance Video • 55 minutes ago 43:53 Homebuyer advice and mistakes, budgeting strategies for you: Wealth Yahoo Finance Video • 1 hour ago View Comments",
#    'company': 'AAPL',
#    'link': 'https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html'},
#   'query': 'how is apple stock performing'},
#  {'id': '14',
#   'document': 'company: AAPL\ntitle: Zacks Value Trader Highlights: Berkshire Hathaway, Apple, American Express, Visa and Coca-Cola\nfull_text: For Immediate Release Chicago, IL – February 18, 2025 – Zacks Value Trader is a podcast hosted weekly by Zacks Stock Strategist Tracey Ryniec. Every week, Tracey will be joined by guests to discuss the hottest investing topics in stocks, bonds and ETFs and how it impacts your life. To listen to the podcast, click here: https://www.zacks.com/stock/news/2416472/3-lessons-from-buffetts-apple-stock-sales) 3 Lessons from Buffett\'s Apple Stock Sales Welcome to Episode #396 of the Value Investor Podcast. (0:30) - How Much Should You Follow The 13-F Filings? (4:10) - Investing Lessons To Learn From Warren Buffett (27:45) - Episode Roundup: BRK.B, AAPL, COST, V, AXP Podcast@Zacks.com Every week, Tracey Ryniec, the editor of Zacks Value Investor portfolio, shares some of her top value investing tips and stock picks. Almost a year ago, Wall Street learned that Berkshire Hathaway (BRK.B) was selling lots of shares of its largest equity holding, Apple. Apple is one of the "4 pillars" of Berkshire Hathaway and a key component of the business. At the May 2024 Berkshire Hathaway annual meeting, Warren Buffett said they were selling for tax reasons. But the selling of the shares continued. As of the third quarter of 2024, Berkshire had sold 100 million shares. It now owns just 300 million. Apple is now just 26.2% of the Berkshire Hathaway equity portfolio, down from around 50%. There are three important lessons value investors can learn from Buffett\'s sale of Apple shares. 1. Buy and hold forever is a myth 2. Don\'t fall in love with your stocks 3. You can\'t market time Valuations: Does It Matter? 1. Apple Inc. AAPL When Berkshire Hathaway bought Apple in the first quarter of 2016, it was cheap on a price-to-earnings (P/E) basis. It had a P/E under 15, which usually indicates a company is a value. But Apple is now trading with a forward P/E of 32.3%. And Apple has a PEG ratio, which measures the P/E divided by growth, of 2.4. A PEG ratio under 1.0 indicates a company has both value and growth. But Apple is more expensive. Will we ever really find out why Buffett decided to start selling Apple in 2024? 2. American Express Co. AXP American Express is now Berkshire Hathaway\'s second largest holding in its equity portfolio. It makes up 15.4% of the portfolio. Shares of American Express have been on a tear the last year, adding 47%. Yet American Express still has attractive valuations. It trades with a forward P/E of 20 and has a PEG ratio of 1.5. Is this a buying opportunity in American Express? 3. Visa Inc. V Story Continues Visa is also a holding in the Berkshire Hathaway equity portfolio. Buffett bought it in 2011 and has never sold, or bought, more shares even as valuations soared in 2020 and 2021. Visa traded over 40x during the pandemic. It was a small position originally, and remains so, even though the shares were up 27.8% over the last year. Yet, Visa is still trading with a forward P/E of 31. That is "cheaper" than Apple but it\'s too high to be considered a classic value stock. Should investors follow Berkshire Hathaway into Visa in 2025? 4. The Coca-Cola Co. KO Coca-Cola has been part of Berkshire Hathaway\'s portfolio for decades. It remains one of the largest positions in the equity portfolio, at 10.8%. Shares of Coke are up 16.9% over the last year. It\'s not cheap, with a forward P/E of 23.5. Coca-Cola also has a PEG ratio of 3.8. A PEG under 1.0 indicates growth and value. Is Coca-Cola still a buy in 2025? What Else Should You Know About Buffett\'s Sales of Apple Shares? Tune into this week\'s podcast to find out. Why Haven\'t You Looked at Zacks\' Top Stocks? Since 2000, our top stock-picking strategies have blown away the S&P\'s +7.7% average gain per year. Amazingly, they soared with average gains of +48.4%, +50.2% and +56.7% per year. Today you can access their live picks without c ...
#   'metadata': {'title': 'Zacks Value Trader Highlights: Berkshire Hathaway, Apple, American Express, Visa and Coca-Cola',
#    'full_text': 'For Immediate Release Chicago, IL – February 18, 2025 – Zacks Value Trader is a podcast hosted weekly by Zacks Stock Strategist Tracey Ryniec. Every week, Tracey will be joined by guests to discuss the hottest investing topics in stocks, bonds and ETFs and how it impacts your life. To listen to the podcast, click here: https://www.zacks.com/stock/news/2416472/3-lessons-from-buffetts-apple-stock-sales) 3 Lessons from Buffett\'s Apple Stock Sales Welcome to Episode #396 of the Value Investor Podcast. (0:30) - How Much Should You Follow The 13-F Filings? (4:10) - Investing Lessons To Learn From Warren Buffett (27:45) - Episode Roundup: BRK.B, AAPL, COST, V, AXP Podcast@Zacks.com Every week, Tracey Ryniec, the editor of Zacks Value Investor portfolio, shares some of her top value investing tips and stock picks. Almost a year ago, Wall Street learned that Berkshire Hathaway (BRK.B) was selling lots of shares of its largest equity holding, Apple. Apple is one of the "4 pillars" of Berkshire Hathaway and a key component of the business. At the May 2024 Berkshire Hathaway annual meeting, Warren Buffett said they were selling for tax reasons. But the selling of the shares continued. As of the third quarter of 2024, Berkshire had sold 100 million shares. It now owns just 300 million. Apple is now just 26.2% of the Berkshire Hathaway equity portfolio, down from around 50%. There are three important lessons value investors can learn from Buffett\'s sale of Apple shares. 1. Buy and hold forever is a myth 2. Don\'t fall in love with your stocks 3. You can\'t market time Valuations: Does It Matter? 1. Apple Inc. AAPL When Berkshire Hathaway bought Apple in the first quarter of 2016, it was cheap on a price-to-earnings (P/E) basis. It had a P/E under 15, which usually indicates a company is a value. But Apple is now trading with a forward P/E of 32.3%. And Apple has a PEG ratio, which measures the P/E divided by growth, of 2.4. A PEG ratio under 1.0 indicates a company has both value and growth. But Apple is more expensive. Will we ever really find out why Buffett decided to start selling Apple in 2024? 2. American Express Co. AXP American Express is now Berkshire Hathaway\'s second largest holding in its equity portfolio. It makes up 15.4% of the portfolio. Shares of American Express have been on a tear the last year, adding 47%. Yet American Express still has attractive valuations. It trades with a forward P/E of 20 and has a PEG ratio of 1.5. Is this a buying opportunity in American Express? 3. Visa Inc. V Story Continues Visa is also a holding in the Berkshire Hathaway equity portfolio. Buffett bought it in 2011 and has never sold, or bought, more shares even as valuations soared in 2020 and 2021. Visa traded over 40x during the pandemic. It was a small position originally, and remains so, even though the shares were up 27.8% over the last year. Yet, Visa is still trading with a forward P/E of 31. That is "cheaper" than Apple but it\'s too high to be considered a classic value stock. Should investors follow Berkshire Hathaway into Visa in 2025? 4. The Coca-Cola Co. KO Coca-Cola has been part of Berkshire Hathaway\'s portfolio for decades. It remains one of the largest positions in the equity portfolio, at 10.8%. Shares of Coke are up 16.9% over the last year. It\'s not cheap, with a forward P/E of 23.5. Coca-Cola also has a PEG ratio of 3.8. A PEG under 1.0 indicates growth and value. Is Coca-Cola still a buy in 2025? What Else Should You Know About Buffett\'s Sales of Apple Shares? Tune into this week\'s podcast to find out. Why Haven\'t You Looked at Zacks\' Top Stocks? Since 2000, our top stock-picking strategies have blown away the S&P\'s +7.7% average gain per year. Amazingly, they soared with average gains of +48.4%, +50.2% and +56.7% per year. Today you can access their live picks without cost or obligation. See Stocks Free >> Tracey Ryniec is the Value Stock Strategist for Zacks.com. She is also the Editor of the\ ...
#    'link': 'https://finance.yahoo.com/news/zacks-value-trader-highlights-berkshire-142000797.html',
#    'company': 'AAPL'},
#   'query': 'how is apple stock performing'},
#  {'id': '100',
#   'document': 'company: INTC\ntitle: Intel (INTC) Stock Trades Up, Here Is Why\nfull_text: Intel (INTC) Stock Trades Up, Here Is Why What Happened? Shares of computer processor maker Intel (NASDAQ:INTC) jumped 10.5% in the afternoon session after The Wall Street Journal reported that the company is in talks with Broadcom and TSMC to sell certain assets. Sources revealed Broadcom is interested in Intel\'s product business, while TSMC is more focused on snapping up and controlling some of its factories. Investors are betting on management to make a move to unlock value in some of its operating segments, given the significant investments that have been made in recent years. The stock\'s reaction suggests the market sees real potential in a deal with industry peers like Broadcom and TSMC, both leaders in chip design and manufacturing. Is now the time to buy Intel? Access our full analysis report here, it’s free. What The Market Is Telling Us Intel’s shares are very volatile and have had 23 moves greater than 5% over the last year. But moves this big are rare even for Intel and indicate this news significantly impacted the market’s perception of the business. The previous big move we wrote about was 7 days ago when the stock gained 8.7% on the news that Vice President JD Vance announced at the AI Action Summit in Paris that the US will provide regulatory measures to protect the country\'s artificial intelligence technologies from "theft and misuse." The global AI race is intensifying across industries, but few are as critical as semiconductors, where AI-powered chips run smart data centers, large language models like ChatGPT, and self-driving cars. Intel has recently won government grants to build facilities to manufacture cutting-edge semiconductor chips on US soil in the coming years, a move that could help improve the company\'s competitiveness. The Vice President\'s comments suggest Intel and other US innovators could benefit from measures that help protect valuable intellectual property, especially in artificial intelligence, ensuring their innovations drive sales and expand market share both domestically and internationally. Intel is up 28.8% since the beginning of the year, but at $26.04 per share, it is still trading 43.6% below its 52-week high of $46.15 from March 2024. Investors who bought $1,000 worth of Intel’s shares 5 years ago would now be looking at an investment worth $393.76. Today’s young investors likely haven’t read the timeless lessons in Gorilla Game: Picking Winners In High Technology because it was written more than 20 years ago when Microsoft and Apple were first establishing their supremacy. But if we apply the same principles, then enterprise software stocks leveraging their own generative AI capabilities may well be the Gorillas of the future. So, in that spirit, we are excited to present our Special Free Report on a profitable, fast-growing enterprise software stock that is already riding the automation wave and looking to catch the generative AI next. View Comments\nlink: https://finance.yahoo.com/news/intel-intc-stock-trades-why-175148102.html\n',
#   'metadata': {'title': 'Intel (INTC) Stock Trades Up, Here Is Why',
#    'full_text': 'Intel (INTC) Stock Trades Up, Here Is Why What Happened? Shares of computer processor maker Intel (NASDAQ:INTC) jumped 10.5% in the afternoon session after The Wall Street Journal reported that the company is in talks with Broadcom and TSMC to sell certain assets. Sources revealed Broadcom is interested in Intel\'s product business, while TSMC is more focused on snapping up and controlling some of its factories. Investors are betting on management to make a move to unlock value in some of its operating segments, given the significant investments that have been made in recent years. The stock\'s reaction suggests the market sees real potential in a deal with industry peers like Broadcom and TSMC, both leaders in chip design and manufacturing. Is now the time to buy Intel? Access our full analysis report here, it’s free. What The Market Is Telling Us Intel’s shares are very volatile and have had 23 moves greater than 5% over the last year. But moves this big are rare even for Intel and indicate this news significantly impacted the market’s perception of the business. The previous big move we wrote about was 7 days ago when the stock gained 8.7% on the news that Vice President JD Vance announced at the AI Action Summit in Paris that the US will provide regulatory measures to protect the country\'s artificial intelligence technologies from "theft and misuse." The global AI race is intensifying across industries, but few are as critical as semiconductors, where AI-powered chips run smart data centers, large language models like ChatGPT, and self-driving cars. Intel has recently won government grants to build facilities to manufacture cutting-edge semiconductor chips on US soil in the coming years, a move that could help improve the company\'s competitiveness. The Vice President\'s comments suggest Intel and other US innovators could benefit from measures that help protect valuable intellectual property, especially in artificial intelligence, ensuring their innovations drive sales and expand market share both domestically and internationally. Intel is up 28.8% since the beginning of the year, but at $26.04 per share, it is still trading 43.6% below its 52-week high of $46.15 from March 2024. Investors who bought $1,000 worth of Intel’s shares 5 years ago would now be looking at an investment worth $393.76. Today’s young investors likely haven’t read the timeless lessons in Gorilla Game: Picking Winners In High Technology because it was written more than 20 years ago when Microsoft and Apple were first establishing their supremacy. But if we apply the same principles, then enterprise software stocks leveraging their own generative AI capabilities may well be the Gorillas of the future. So, in that spirit, we are excited to present our Special Free Report on a profitable, fast-growing enterprise software stock that is already riding the automation wave and looking to catch the generative AI next. View Comments',
#    'company': 'INTC',
#    'link': 'https://finance.yahoo.com/news/intel-intc-stock-trades-why-175148102.html'},
#   'query': 'how is apple stock performing'},
#  {'id': '6',
#   'document': 'company: AAPL\ntitle: Apple Could Announce a New iPhone Tomorrow. It May Not Boost the Stock.\nfull_text: Apple will unveil a product tomorrow, but Wall Street is already pretty sure what it is. Chief Executive Officer Tim Cook wrote, “Get ready to meet the newest member of the family,” in an X post last week. The post also said that there will be an Apple launch on Wednesday. Continue Reading View Comments\nlink: https://finance.yahoo.com/m/20230221-638c-325c-8e36-94fd2cab7a87/apple-could-announce-a-new.html\n',
#   'metadata': {'title': 'Apple Could Announce a New iPhone Tomorrow. It May Not Boost the Stock.',
#    'link': 'https://finance.yahoo.com/m/20230221-638c-325c-8e36-94fd2cab7a87/apple-could-announce-a-new.html',
#    'full_text': 'Apple will unveil a product tomorrow, but Wall Street is already pretty sure what it is. Chief Executive Officer Tim Cook wrote, “Get ready to meet the newest member of the family,” in an X post last week. The post also said that there will be an Apple launch on Wednesday. Continue Reading View Comments',
#    'company': 'AAPL'},
#   'query': 'Latest news about how is apple stock performing'},
#  {'id': '4',
#   'document': "company: AAPL\ntitle: Apple Partners With Alibaba, Eyes Baidu for AI Expansion in China\nfull_text: Apple (AAPL, Financials) partnered with Alibaba (BABA, Financials) and is exploring a potential collaboration with Baidu (BIDU, Financials) to enhance its artificial intelligence capabilities in China, according to Wedbush Securities. Warning! GuruFocus has detected 7 Warning Signs with DEXSF. Over the previous year, the firm has seen market share losses to Huawei. Wedbush, however, hopes Apple's AI-driven developmentsalong with forthcoming iPhone 16 and iPhone 17 introductionswill assist to restore ground lost. Analyst Dan Ives sees Apple Intelligence as a main driver of iPhone upgrades, especially in areas where the technology has already been launched. China should have the AI capability by April or May. Wedbush projects that ultimately 25% of the world's population will access artificial intelligence via an Apple device. Apple is hoping to stimulate expansion in China by creating an ecosystem of AI-powered apps grounded on Apple Intelligence. The project is supposed to generate fresh income and propel customer improvements. With a 1% year-over-year drop in iPhone income for the past quarter$69.14 billionApple fell short of the $71.04 billion expectation. Greater China's revenue also fell to $18.51 billion. China still presents a hurdle for Apple, but Wedbush notes simpler year-over-year comparisons and expects development to start in the area from the June quarter forward. Based on the Alibaba AI alliance, Wedbush thinks Apple CEO Tim Cook has properly handled the company's strategy in China despite continuous geopolitical concerns between the U.S. and China. Wedbush maintained an Outperform rating on Apple shares and set a $325 price target. This article first appeared on GuruFocus. View Comments\nlink: https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html\n",
#   'metadata': {'title': 'Apple Partners With Alibaba, Eyes Baidu for AI Expansion in China',
#    'link': 'https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html',
#    'full_text': "Apple (AAPL, Financials) partnered with Alibaba (BABA, Financials) and is exploring a potential collaboration with Baidu (BIDU, Financials) to enhance its artificial intelligence capabilities in China, according to Wedbush Securities. Warning! GuruFocus has detected 7 Warning Signs with DEXSF. Over the previous year, the firm has seen market share losses to Huawei. Wedbush, however, hopes Apple's AI-driven developmentsalong with forthcoming iPhone 16 and iPhone 17 introductionswill assist to restore ground lost. Analyst Dan Ives sees Apple Intelligence as a main driver of iPhone upgrades, especially in areas where the technology has already been launched. China should have the AI capability by April or May. Wedbush projects that ultimately 25% of the world's population will access artificial intelligence via an Apple device. Apple is hoping to stimulate expansion in China by creating an ecosystem of AI-powered apps grounded on Apple Intelligence. The project is supposed to generate fresh income and propel customer improvements. With a 1% year-over-year drop in iPhone income for the past quarter$69.14 billionApple fell short of the $71.04 billion expectation. Greater China's revenue also fell to $18.51 billion. China still presents a hurdle for Apple, but Wedbush notes simpler year-over-year comparisons and expects development to start in the area from the June quarter forward. Based on the Alibaba AI alliance, Wedbush thinks Apple CEO Tim Cook has properly handled the company's strategy in China despite continuous geopolitical concerns between the U.S. and China. Wedbush maintained an Outperform rating on Apple shares and set a $325 price target. This article first appeared on GuruFocus. View Comments",
#    'company': 'AAPL'},
#   'query': 'how is apple stock performing financial performance'},
#  {'id': '22',
#   'document': 'company: MSFT\ntitle: Here’s Why Microsoft (MSFT) Stock Returned 13% in Q4\nfull_text: Bretton Capital Management, an investment management company, released “Bretton Fund” fourth quarter 2024 investor letter. A copy of the letter can be downloaded here. The market is experiencing a period of high returns, with two consecutive years of around 25% returns and 15 years of mid-teens returns, prompting investors to be cautious. The average stock market return is around 9-10% per year, historically, based on corporate earnings growth and dividends and buybacks. The 20 companies the fund owns are well-positioned and expected to perform well. Against this backdrop, in the fourth quarter, the fund returned -0.98% compared to 2.41% return for the S&P 500. In addition, you can check the fund’s top 5 holdings to determine its best picks for 2024. In its fourth quarter 2024 investor letter, Bretton Fund emphasized stocks such as Microsoft Corporation (NASDAQ:MSFT). Microsoft Corporation (NASDAQ:MSFT) is a multinational software company that develops and supports software, services, devices, and solutions. The one-month return of Microsoft Corporation (NASDAQ:MSFT) was -4.80%, and its shares gained 1.08% of their value over the last 52 weeks. On February 14, 2025, Microsoft Corporation (NASDAQ:MSFT) stock closed at $408.43 per share with a market capitalization of $3.04 trillion. Bretton Fund stated the following regarding Microsoft Corporation (NASDAQ:MSFT) in its Q4 2024 investor letter: "Microsoft Corporation (NASDAQ:MSFT) has become the go-to provider of computing services for many emerging AI companies, and its franchise is much more diversified than Alphabet’s, making it a net beneficiary of the AI arms race. Demand for its cloud computing services continued to grow, and the rest of its business (Orce, Windows, Xbox, GitHub, LinkedIn) are also thriving, sending earnings per share up 22% while the stock returned 13%." Is Microsoft Corp. (MSFT) the Most Profitable Tech Stock to Buy Now? A development team working together to create the next version of Windows. Microsoft Corporation (NASDAQ:MSFT) is in second position our list of\xa030 Most Popular Stocks Among Hedge Funds. As per our database, 279 hedge fund portfolios held Microsoft Corporation (NASDAQ:MSFT) at the end of the third quarter which was 279 in the previous quarter. In the\xa0fiscal second quarter of 2025, Microsoft Corporation (NASDAQ:MSFT)\xa0reported\xa0$69.6 billion in revenues, up 12% year-over-year. While we acknowledge the potential of Microsoft Corporation (NASDAQ:MSFT) as an investment, our conviction lies in the belief that AI stocks hold greater promise for delivering higher returns, and doing so within a shorter timeframe. If you are looking for an AI stock that is as promising as NVIDIA but that trades at less than 5 times its earnings, check out our report about the\xa0cheapest AI stock. Story Continues In\xa0another article we discussed Microsoft Corporation (NASDAQ:MSFT) and shared the list of most profitable tech stocks to buy. In addition, please check out our hedge fund investor letters Q4 2024\xa0page for more investor letters from hedge funds and other leading investors. READ NEXT:\xa0Michael Burry Is Selling These Stocks\xa0and\xa0A New Dawn Is Coming to US Stocks. Disclosure: None. This article is originally published at Insider Monkey. View Comments\nlink: https://finance.yahoo.com/news/why-microsoft-msft-stock-returned-142857739.html\n',
#   'metadata': {'full_text': 'Bretton Capital Management, an investment management company, released “Bretton Fund” fourth quarter 2024 investor letter. A copy of the letter can be downloaded here. The market is experiencing a period of high returns, with two consecutive years of around 25% returns and 15 years of mid-teens returns, prompting investors to be cautious. The average stock market return is around 9-10% per year, historically, based on corporate earnings growth and dividends and buybacks. The 20 companies the fund owns are well-positioned and expected to perform well. Against this backdrop, in the fourth quarter, the fund returned -0.98% compared to 2.41% return for the S&P 500. In addition, you can check the fund’s top 5 holdings to determine its best picks for 2024. In its fourth quarter 2024 investor letter, Bretton Fund emphasized stocks such as Microsoft Corporation (NASDAQ:MSFT). Microsoft Corporation (NASDAQ:MSFT) is a multinational software company that develops and supports software, services, devices, and solutions. The one-month return of Microsoft Corporation (NASDAQ:MSFT) was -4.80%, and its shares gained 1.08% of their value over the last 52 weeks. On February 14, 2025, Microsoft Corporation (NASDAQ:MSFT) stock closed at $408.43 per share with a market capitalization of $3.04 trillion. Bretton Fund stated the following regarding Microsoft Corporation (NASDAQ:MSFT) in its Q4 2024 investor letter: "Microsoft Corporation (NASDAQ:MSFT) has become the go-to provider of computing services for many emerging AI companies, and its franchise is much more diversified than Alphabet’s, making it a net beneficiary of the AI arms race. Demand for its cloud computing services continued to grow, and the rest of its business (Orce, Windows, Xbox, GitHub, LinkedIn) are also thriving, sending earnings per share up 22% while the stock returned 13%." Is Microsoft Corp. (MSFT) the Most Profitable Tech Stock to Buy Now? A development team working together to create the next version of Windows. Microsoft Corporation (NASDAQ:MSFT) is in second position our list of\xa030 Most Popular Stocks Among Hedge Funds. As per our database, 279 hedge fund portfolios held Microsoft Corporation (NASDAQ:MSFT) at the end of the third quarter which was 279 in the previous quarter. In the\xa0fiscal second quarter of 2025, Microsoft Corporation (NASDAQ:MSFT)\xa0reported\xa0$69.6 billion in revenues, up 12% year-over-year. While we acknowledge the potential of Microsoft Corporation (NASDAQ:MSFT) as an investment, our conviction lies in the belief that AI stocks hold greater promise for delivering higher returns, and doing so within a shorter timeframe. If you are looking for an AI stock that is as promising as NVIDIA but that trades at less than 5 times its earnings, check out our report about the\xa0cheapest AI stock. Story Continues In\xa0another article we discussed Microsoft Corporation (NASDAQ:MSFT) and shared the list of most profitable tech stocks to buy. In addition, please check out our hedge fund investor letters Q4 2024\xa0page for more investor letters from hedge funds and other leading investors. READ NEXT:\xa0Michael Burry Is Selling These Stocks\xa0and\xa0A New Dawn Is Coming to US Stocks. Disclosure: None. This article is originally published at Insider Monkey. View Comments',
#    'link': 'https://finance.yahoo.com/news/why-microsoft-msft-stock-returned-142857739.html',
#    'title': 'Here’s Why Microsoft (MSFT) Stock Returned 13% in Q4',
#    'company': 'MSFT'},
#   'query': 'how is apple stock performing financial performance'}]

# %%
with open("keys.json") as f:
    keys = json.load(f)

llama_key = keys["llama_api_key"]
gemini_key = keys["gemini_api_key"]
mistral_key = keys["mistral_api_key"]
cohere_key = keys["cohere_api_key"]

# %%
# Check if have access to Gemini
client = genai.Client(api_key=gemini_key)

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=["whats your name"]
)
print(response.text)
# Out:
# I am a large language model, trained by Google.

# %%
def generate_rag_response(query, context, links):
    # Format the prompt with retrieved context and links
    prompt = f"""
    You are a knowledgeable financial news assistant with a deep understanding of companies, stock performance, and market events.

    Use the following retrieved news articles to answer the user's financial question clearly and accurately.

    User Query:
    {query}

    Retrieved News Articles:
    {context}

    Based on this information, write a helpful and well-organized answer to the user’s question.
    Summarize relevant insights across the articles — such as stock movements, earnings, leadership changes, AI updates, regulations, or market sentiment.

    Do not include source links in your answer.
    """

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=[prompt],
        config={"response_mime_type": "text/plain"}
    )

    return response.text


def news_rag(user_query):
    # Step 1: Retrieve relevant documents
    results = retrieve_news_info(user_query)

    # Step 2: Format context from documents
    context = "\n\n".join([res['document'] for res in results])

    # Step 3: Extract links for reference
    links = [res['metadata']['link'] for res in results if 'link' in res['metadata']]

    # Step 4: Generate the final RAG-based answer
    response = generate_rag_response(user_query, context, links)

    # Step 5: Append source links to the response
    if links:
        response += "\n\nSources:\n" + "\n".join(links)

    return response, results

# %%
response, results = news_rag("how is apple stock performing")

# %%
print(response)
# Out:
# Here's an overview of how Apple (AAPL) stock is performing, based on recent news:
#
# **Stock Performance & Valuation:**
#
# *   **Positive Gains:** Apple's shares have increased by 27.1% over the past year.
# *   **Valuation Concerns:** While Berkshire Hathaway bought Apple when it had a P/E under 15, Apple's valuation is now higher, with a forward P/E of 32.3 and a PEG ratio of 2.4.
# *   **Analyst Target:** One analyst from Morgan Stanley reaffirmed an "Overweight" rating with a price target of $275.
# *   **General Bullishness:** Despite some shifts, Wall Street generally feels bullish.
#
# **Financial Performance:**
#
# *   **Steady Growth:** Apple reported steady Q1 2025 results, with 4% year-over-year sales growth.
# *   **Services Growth:** Sales growth was primarily driven by the 'Services' segment, which rose 14% year-over-year.
# *   **Product Performance:** Mac and iPad sales increased by around 15% each, but iPhone and Wearables sales were down slightly (1-2%).
# *   **Profitability:** Apple has an operating margin of 32% and a net profit margin of 24%.
#
# **Factors Influencing Stock:**
#
# *   **AI Initiatives:** Introduction of "Apple Intelligence" is expected to help push shares higher. Apple is partnering with Alibaba and potentially Baidu to enhance AI capabilities in China.
# *   **iPhone Performance:** Weakness in iPhone sales, particularly in China, is a concern. However, a strong launch is predicted for the iPhone SE 4.
# *   **Market Trends:** Fund managers may be moving away from the "Magnificent Seven" tech stocks, which could impact Apple.
#
# **Other Considerations:**
#
# *   **Shareholder Returns:** Apple returned over $30 billion to shareholders in a recent quarter through dividends and share repurchases.
# *   **Overall Ranking:** Apple ranks as one of the most profitable tech stocks.
#
#
# Sources:
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/zacks-analyst-blog-highlights-apple-144800950.html
# https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html
# https://finance.yahoo.com/news/zacks-value-trader-highlights-berkshire-142000797.html
# https://finance.yahoo.com/news/intel-intc-stock-trades-why-175148102.html
# https://finance.yahoo.com/m/20230221-638c-325c-8e36-94fd2cab7a87/apple-could-announce-a-new.html
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/why-microsoft-msft-stock-returned-142857739.html

# %%
# Test financial queries
test_queries = [
    "How has Tesla's stock been performing lately?",
    "Is Microsoft making any new AI-related moves?",
    "Recent financial news about Nvidia and the semiconductor industry"
]

for query in test_queries:
    print(f"\nQuery: {query}")
    response, _ = news_rag(query)  # Ignore the results here
    print("\nResponse:")
    print(response)
    print("-" * 60)
# Out:
# Query: How has Tesla's stock been performing lately?
#
# Response:
# Tesla's stock performance is viewed in the retrieved articles from a few different angles:
#
# *   **ELON ETF:** A new ETF, Battleshares TSLA vs F ETF (ELON), was launched that pairs a leveraged long position in Tesla with a short position in Ford. This ETF is designed to benefit if Tesla's stock outperforms Ford's.
# *   **Magnificent Seven:** Bank of America's global fund manager survey indicates that fund managers are moving away from the "Magnificent Seven" tech stocks, which includes Tesla, and focusing more on global equities, gold, and small-cap US stocks.
# *   **Bearish Sentiment:** In one article, Tesla is mentioned in the context of policy shifts potentially moving towards business unfriendliness.
#
#
# Sources:
# https://finance.yahoo.com/news/cerence-rises-75-date-buy-144900404.html
# https://finance.yahoo.com/news/tesla-vs-ford-etf-elon-165500695.html
# https://finance.yahoo.com/news/tesla-vs-ford-etf-elon-165500695.html
# https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html
# https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html
# https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html
# https://finance.yahoo.com/news/jim-cramer-nvidia-nvda-think-115144647.html
# https://finance.yahoo.com/news/why-microsoft-msft-stock-returned-142857739.html
# ------------------------------------------------------------
#
# Query: Is Microsoft making any new AI-related moves?
#
# Response:
# Yes, Microsoft is making several new AI-related moves:
#
# *   **Partnership with OpenAI:** Microsoft is integrating GPT-4 technology across its cloud and software products through its partnership with OpenAI and holds a significant stake in the company.
# *   **Azure AI Cloud:** Microsoft is taking steps into quantum computing with Azure Quantum Cloud, which gives customers access to quantum hardware and allows them to build and refine quantum algorithms. Microsoft's AI offerings have an annualized revenue run rate of $13 billion, a 175% increase.
# *   **Focus on AI Integration:** Microsoft is focused on integrating AI across its products to enhance data processing capabilities and operational efficiency.
# *   **AI-Driven Cloud Services Growth:** Microsoft's CFO, Amy Hood, remains optimistic about AI-driven cloud services growth. Microsoft expects Azure revenue growth to be between 31% and 32% in constant currency driven by strong demand for its portfolio of services, with the contribution from AI services increasing.
# *   **Capitalizing on Generative AI (GenAI):** RBC Capital Markets favors Microsoft for its position to capitalize on generative AI and its increased spending on technology development.
#
# Sources:
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/news/microsoft-msft-most-profitable-tech-203248725.html
# ------------------------------------------------------------
#
# Query: Recent financial news about Nvidia and the semiconductor industry
#
# Response:
# Here's a summary of recent financial news regarding Nvidia and the semiconductor industry:
#
# **Earnings and Outlook:**
#
# *   Nvidia is expected to modestly beat earnings expectations for its fiscal Q4 results, which will be reported on February 26.
# *   However, the company's first-quarter outlook may face challenges due to the transition to Blackwell chips, a potential decline in Hopper chip demand, and ongoing restrictions in China.
# *   Despite near-term pressures, Bank of America remains optimistic about Nvidia's long-term potential, considering it a computing platform rather than just a chipmaker.
# *   Analysts estimate 73% revenue growth, and there is a strong track record of exceeding expectations.
#
# **Stock Performance and Valuation:**
#
# *   Nvidia's stock has recently climbed, clearing a key resistance level, and is approaching levels seen before concerns about DeepSeek emerged.
# *   An AI sell-off had briefly brought the stock down, but it's recovering.
# *   Nvidia's valuation is considered attractive by some, trading at 31x projected 2025 earnings and 24x for 2026, which is on the lower end of its historical range.
# *   Compared to other big tech companies, Nvidia's forward earnings perspective is cheaper than Apple's and Microsoft's.
#
# **Upcoming Catalysts and Developments:**
#
# *   Nvidia's upcoming GTC conference on March 17 is seen as a major catalyst.
# *   The company is expected to unveil its GB300 and Rubin chips and showcase expansion plans into robotics and quantum computing.
# *   The South Korean government plans to buy 10,000 graphic processing units to build an artificial intelligence computing center lifted shares.
#
# **Strategic Moves:**
#
# *   Nvidia has reduced its stake in Arm Holdings by 44%. This may be related to Arm's plans to compete directly with its customers, including Nvidia, by designing and selling its own processors.
# *   Nvidia has unveiled a new stake in China-based WeRide, a client that uses Nvidia's software and GPUs for autonomous vehicles, and Nebius Group, an AI-focused tech group.
# *   The company has closed out prior holdings in SoundCloud and Serve Robotics.
#
# **Industry Trends:**
#
# *   The Philadelphia Semiconductor Index has shown positive performance, increasing by 3% last week, outperforming the S&P 500.
# *   The market is anticipating another peak in AI hardware spending in 2025, with major companies like Meta and Alphabet planning significant capital expenditures on AI hardware.
# *   Bank of America's global fund manager survey indicates that fund managers are moving away from the "Magnificent Seven" tech stocks (including Nvidia) and focusing more on global equities, gold, and small-cap US stocks.
#
#
# Sources:
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/d27e7c4c-2bb0-323d-8610-fb1eb057a898/nvidia-%28nvda%29-stock-quotes%2C.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html
# https://finance.yahoo.com/news/jim-cramer-nvidia-nvda-think-115144647.html
# https://finance.yahoo.com/video/nvidia-gains-baidu-earnings-walgreens-171328790.html
# https://finance.yahoo.com/m/dc591aa5-8656-399f-a2b0-90fb4c8c329e/nvidia-soars-as-stargate.html
# ------------------------------------------------------------

# %% [markdown]
# ### 4.2 Hyde Retrieval

# %%
def hyde_retrieval(query, n_results=5):
    """Use HyDE to retrieve financial news more effectively."""

    # Step 1: Generate a hypothetical financial news-style document
    hyde_prompt = f"""
    You are a financial analyst. Write a detailed news-style explanation that would best answer this user's question:

    "{query}"

    Include relevant events, companies, stock performance, financial terms, and context where appropriate.
    """

    hyde_response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=[hyde_prompt],
        config={
            "response_mime_type": "text/plain"
        }
    )

    hypothetical_document = hyde_response.text

    # Step 2: Create embedding from the generated text
    hyde_embedding = model.encode(hypothetical_document).tolist()

    # Step 3: Retrieve similar documents using vector search
    results = collection.query(
        query_embeddings=[hyde_embedding],
        n_results=n_results
    )

    # Step 4: Format the results
    formatted_results = []
    for doc, metadata, id in zip(results['documents'][0],
                                 results['metadatas'][0],
                                 results['ids'][0]):
        formatted_results.append({
            'id': id,
            'document': doc,
            'metadata': metadata,
            'query': query
        })

    return formatted_results


def finance_hyde_rag(user_query):
    # Step 1: Retrieve relevant documents using HyDE
    results = hyde_retrieval(user_query, n_results=15)

    # Step 2: Format retrieved context
    context = "\n\n".join([res['document'] for res in results])

    # Step 3: Generate plain language answer (with sources appended externally)
    response = generate_rag_response(user_query, context)

    return response, results

# %%
response, results = news_rag("how is apple stock performing")

# %%
print(response)
# Out:
# Here's a summary of how Apple (AAPL) stock is performing, based on recent news:
#
# **Stock Performance & Trends:**
#
# *   **Overall Positive Trend:** Apple shares have generally performed well, with a gain of +27.1% over the past year.
# *   **Analyst Ratings:** A Morgan Stanley analyst reaffirmed an "Overweight" rating with a price target of $275. Wedbush maintained an Outperform rating on Apple shares and set a $325 price target.
# *   **Valuation:** Apple is currently trading with a forward P/E of 32.3 and a PEG ratio of 2.4, suggesting it's not considered a classic value stock.
# *   **Growth:** Apple expects revenues for the March quarter (second quarter fiscal 2025) to grow in the low to mid-single digits year-over-year, with the Services segment expected to grow at a low double-digit rate.
#
# **Factors Influencing the Stock:**
#
# *   **Strong Services Growth:** Apple's growth is significantly driven by its Services segment, which includes subscriptions and digital content. The company has over 1 billion paid subscribers across its Services.
# *   **Apple Intelligence:** The introduction of Apple Intelligence is expected to help push the stock higher.
# *   **iPhone Sales:** Weakness in iPhone sales, particularly in China, is a concern.
# *   **AI Expansion:** Apple is partnering with Alibaba and exploring collaboration with Baidu to enhance its AI capabilities in China.
# *   **Broader Market Trends:** There's a general shift in the market away from the "Magnificent Seven" tech stocks, with fund managers focusing more on global equities, gold, and small-cap US stocks.
# *   **Berkshire Hathaway's Activity:** Warren Buffett's Berkshire Hathaway has been selling shares of Apple, primarily for tax reasons, reducing Apple's portion of their portfolio.
#
# **Recent Developments:**
#
# *   **Q1 2025 Results:** Apple reported steady Q1 2025 results with 4% year-over-year sales growth, driven mainly by the Services segment.
# *   **Shareholder Returns:** Apple returned over $30 billion to shareholders in the last quarter through dividends and share repurchases.
# *   **New Product Launch:** A new Apple product is expected to be announced soon.
#
#
# Sources:
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/zacks-analyst-blog-highlights-apple-144800950.html
# https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html
# https://finance.yahoo.com/news/zacks-value-trader-highlights-berkshire-142000797.html
# https://finance.yahoo.com/news/intel-intc-stock-trades-why-175148102.html
# https://finance.yahoo.com/m/20230221-638c-325c-8e36-94fd2cab7a87/apple-could-announce-a-new.html
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/why-microsoft-msft-stock-returned-142857739.html

# %% [markdown]
# ### 4.3 Retrieval with Query Decomposition

# %%
class Query(BaseModel):
    query: str

def decompose_query(query):
    """Decompose complex financial query into simpler sub-queries."""

    decompose_prompt = f"""
    Break down the following complex financial news question into 2–3 simpler sub-questions:
    "{query}"

    The sub-questions should focus on specific companies, stock movements, events, or trends mentioned in the original query.
    Return only the sub-queries in JSON format.
    """

    decompose_response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=[decompose_prompt],
        config={
            "response_mime_type": "application/json",
            "response_schema": list[Query],
        }
    )

    # Parse the response to get sub-queries
    sub_queries = json.loads(decompose_response.text)
    sub_queries = [q['query'].strip() for q in sub_queries]

    return sub_queries

# %%
complex_query = "What recent announcements have Microsoft and Tesla made, and how might these affect their stock performance?"
decompose_query(complex_query)
# Out:
# ['What recent announcements have Microsoft made?',
#  'What recent announcements has Tesla made?',
#  "How might Microsoft's recent announcements affect its stock performance?",
#  "How might Tesla's recent announcements affect its stock performance?"]

# %%
def retrieve_with_decomposition(query, n_results=3):
    """Retrieve relevant financial news using query decomposition for complex queries."""
    print(f"Original query: {query}")

    # Step 1: Decompose the query into simpler sub-queries
    sub_queries = decompose_query(query)
    print(f"Decomposed into: {sub_queries}")

    # Step 2: Retrieve documents for each sub-query
    all_results = []
    for sub_query in sub_queries:
        # Retrieve news results for the sub-query
        sub_results = retrieve_news_info(sub_query, n_results=n_results)
        print(f"Retrieved {len(sub_results)} results for: '{sub_query}'")
        all_results.extend(sub_results)

    # Step 3: Deduplicate results based on unique id
    unique_results = {}
    for result in all_results:
        if result['id'] not in unique_results:
            unique_results[result['id']] = result

    return list(unique_results.values())

def finance_decomposition_rag(user_query):
    # Retrieve documents with decomposition
    results = retrieve_with_decomposition(user_query, n_results=5)

    # Format context
    context = "\n\n".join([res['document'] for res in results])

    # Extract links from metadata
    links = [res['metadata'].get('link') for res in results if 'link' in res['metadata'] and res['metadata']['link']]

    # Generate response (without links inside prompt)
    response = generate_rag_response(user_query, context, links)

    # Append links explicitly if needed (optional)
    if links:
        response += "\n\nSources:\n" + "\n".join(links)

    return response, results

# %%
response, results = finance_decomposition_rag(complex_query)
# Out:
# Original query: What recent announcements have Microsoft and Tesla made, and how might these affect their stock performance?
# Decomposed into: ['What recent announcements have Microsoft made?', 'What recent announcements have Tesla made?', "How might Microsoft's and Tesla's recent announcements affect their stock performance?"]
# Retrieved 7 results for: 'What recent announcements have Microsoft made?'
# Retrieved 8 results for: 'What recent announcements have Tesla made?'
# Retrieved 8 results for: 'How might Microsoft's and Tesla's recent announcements affect their stock performance?'

# %%
print(response)
# Out:
# Here's a summary of recent announcements from Microsoft and Tesla and how they might affect their stock performance:
#
# **Microsoft (MSFT)**
#
# *   **Earnings and Revenue:** Microsoft reported strong Q2 FY25 results, with revenue up 12% year-over-year, driven by cloud revenue growth of 21%.
# *   **AI Focus:** Microsoft is heavily focused on integrating AI across its products, which is expected to increase demand for its offerings, particularly its Azure cloud services. CFO Amy Hood anticipates continued revenue growth driven by Azure and AI services.
# *   **Analyst Ratings:** RBC Capital Markets reiterated an "Outperform" rating with a $500 price target, citing Microsoft's diverse market exposure, large installed base, and position to capitalize on generative AI.
# *   **Valuation:** One analysis suggests that Microsoft is fairly valued based on a Discounted Earnings model, while another valuation using free cash flow indicates it may be overvalued.
# *   **Board Changes:** Rashida Hodge, Corporate VP of Customer Success - Azure Data and AI at Microsoft, was appointed to Regal Rexnord Corporation's Board of Directors.
# *   **Market Sentiment:** Fund managers are starting to move away from the "Magnificent Seven" stocks, including Microsoft, and are focusing on global equities and small-cap stocks.
#
# **Potential Impacts on Microsoft's Stock Performance:**
#
# *   Positive earnings and growth in cloud services and AI could drive the stock higher.
# *   Analyst support and price target suggest potential for further gains.
# *   Concerns about valuation and a shift in market sentiment away from big tech could limit stock appreciation.
#
# **Tesla (TSLA)**
#
# *   **New ETF:** Defiance ETFs launched the Battleshares TSLA vs F ETF (ELON), which aims to capitalize on the competition between Tesla and Ford. ELON takes a leveraged long position in Tesla and a short position in Ford.
# *   **ETF Strategy:** ELON ETF's performance depends on Tesla's share price outperforming Ford's. It's designed for investors bullish on Tesla and bearish on Ford but comes with higher risk and volatility due to leveraged positions.
#
# **Potential Impacts on Tesla's Stock Performance:**
#
# *   The ELON ETF could increase trading volume and investor interest in Tesla.
# *   The ETF's success depends on Tesla outperforming Ford. Broader market trends and investor sentiment towards EV companies will influence the stock price.
#
#
#
# Sources:
# https://finance.yahoo.com/news/why-microsoft-msft-stock-returned-142857739.html
# https://finance.yahoo.com/news/rashida-hodge-microsoft-gerben-bakker-130000764.html
# https://finance.yahoo.com/news/enpro-earnings-look-npo-130819583.html
# https://finance.yahoo.com/news/microsoft-msft-most-profitable-tech-203248725.html
# https://finance.yahoo.com/news/zacks-analyst-blog-highlights-apple-144800950.html
# https://finance.yahoo.com/news/microsoft-corp-exploration-intrinsic-value-060941367.html
# https://finance.yahoo.com/news/earnings-watch-amplitude-ampl-reports-130747253.html
# https://finance.yahoo.com/news/tesla-vs-ford-etf-elon-165500695.html
# https://finance.yahoo.com/news/tesla-vs-ford-etf-elon-165500695.html
# https://finance.yahoo.com/news/jim-cramer-nvidia-nvda-think-115144647.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html
# https://finance.yahoo.com/m/6111ff4a-1dcc-3fc2-a0e8-f9cd6cb34931/should-you-buy-apple-stock.html
# https://finance.yahoo.com/news/zacks-analyst-blog-highlights-apple-144800950.html
# https://finance.yahoo.com/video/wall-street-bullish-cash-levels-145356726.html
# https://finance.yahoo.com/news/metas-stock-falls-putting-20-session-streak-at-risk-192124303.html
# https://finance.yahoo.com/news/metas-stock-falls-putting-20-session-streak-at-risk-192124303.html
# https://finance.yahoo.com/news/3-companies-crushed-quarterly-expectations-011300289.html
# https://finance.yahoo.com/video/biggest-risk-market-reality-check-121516770.html

# %% [markdown]
# # Compare responses across different models and prompts

# %%
def call_gemini(prompt):
    from google.generativeai import GenerativeModel, configure

    configure(api_key=gemini_key)
    model = GenerativeModel("gemini-2.0-flash")
    return model.generate_content(prompt).text.strip()


# def call_openai(prompt):
#     client = OpenAI(api_key=openai_key)

#     response = client.chat.completions.create(
#         model="gpt-3.5-turbo",
#         messages=[
#             {"role": "user", "content": prompt}
#         ]
#     )

#     return response.choices[0].message.content.strip()


# def call_deepseek(prompt):
#     client = OpenAI(
#         api_key=deepseek_key,
#         base_url="https://api.deepseek.com"
#     )

#     response = client.chat.completions.create(
#         model="deepseek-chat",
#         messages=[{"role": "user", "content": prompt}]
#     )

#     return response.choices[0].message.content.strip()



def call_llama(prompt):
    client = OpenAI(
        base_url="https://openrouter.ai/api/v1",
        api_key=llama_key,
    )

    response = client.chat.completions.create(
        model="meta-llama/llama-3.3-70b-instruct",
        messages=[
            {"role": "user", "content": prompt}
        ]
    )

    return response.choices[0].message.content.strip()




def call_mistral(prompt):
    """Call Mistral chat model using the official SDK."""
    client = Mistral(api_key=mistral_key)

    response = client.chat.complete(
        model="mistral-small-2506",
        messages=[
            {"role": "user", "content": prompt}
        ]
    )

    return response.choices[0].message.content.strip()


def call_cohere(prompt):
    import cohere
    co = cohere.Client(cohere_key)

    response = co.chat(message=prompt, model="command-r")
    return response.text.strip()

# %%
def generate_rag_response_model_comp(query, context, model_name="gemini", prompt_template=None):
    if prompt_template is None:
        prompt_template = """You are a knowledgeable financial news assistant with expertise in analyzing company announcements, stock trends, and macroeconomic events.

User Query:
{query}

Recent News Context:
{context}

Provide a concise, helpful answer based on the above news. Avoid hallucinating facts or sources.
"""

    prompt = prompt_template.format(query=query, context=context)

    if model_name == "gemini":
        return call_gemini(prompt)
    elif model_name == "llama":
        return call_llama(prompt)
    elif model_name == "mistral":
        return call_mistral(prompt)
    elif model_name == "cohere":
        return call_cohere(prompt)
    else:
        raise ValueError("Unsupported model: " + model_name)

# %%
prompt_templates = {
    "default": """You are a knowledgeable financial news assistant with expertise in analyzing company announcements, stock trends, and macroeconomic events.

User Query:
{query}

Recent News Context:
{context}

Provide a concise, helpful answer based on the above news. Avoid hallucinating facts or sources.
""",

    "bullet_summary": """Summarize the key takeaways from the following financial news in bullet points relevant to this question:

Question: {query}

News Articles:
{context}
""",

    "analyst_voice": """Act like a professional stock analyst. Based on the news provided below, answer the question with precision and clarity.

Query: {query}

News Context:
{context}
"""
}

# %%
def compare_all_models_prompts(query, prompt_templates_dict):
    results = retrieve_with_decomposition(query, n_results=5)
    context = "\n\n".join([res["document"] for res in results])
    links = [res["metadata"].get("link") for res in results if res["metadata"].get("link")]

    models = ["gemini", "cohere", "llama", "mistral"]
    comparison_results = []

    for prompt_name, template in prompt_templates_dict.items():
        for model in models:
            print(f"Running → Model: {model}, Prompt: {prompt_name}")
            try:
                response = generate_rag_response_model_comp(query, context, model_name=model, prompt_template=template)
                if links:
                    response += "\n\nSources:\n" + "\n".join(links)
            except Exception as e:
                response = f"[ERROR] {str(e)}"

            comparison_results.append({
                "model": model,
                "prompt": prompt_name,
                "response": response
            })

    return comparison_results

# %%
query = "What are the latest developments from Apple and Nvidia related to AI and their impact on stock prices?"
all_outputs = compare_all_models_prompts(query, prompt_templates)
# Out:
# Original query: What are the latest developments from Apple and Nvidia related to AI and their impact on stock prices?
# Decomposed into: ['What are the latest AI developments from Apple?', 'What are the latest AI developments from Nvidia?', "How have Apple's and Nvidia's stock prices been affected by recent AI news?"]
# Retrieved 8 results for: 'What are the latest AI developments from Apple?'
# Retrieved 6 results for: 'What are the latest AI developments from Nvidia?'
# Retrieved 7 results for: 'How have Apple's and Nvidia's stock prices been affected by recent AI news?'
# Running → Model: gemini, Prompt: default
# Running → Model: cohere, Prompt: default
# Running → Model: llama, Prompt: default
# Running → Model: mistral, Prompt: default
# Running → Model: gemini, Prompt: bullet_summary
# Running → Model: cohere, Prompt: bullet_summary
# Running → Model: llama, Prompt: bullet_summary
# Running → Model: mistral, Prompt: bullet_summary
# Running → Model: gemini, Prompt: analyst_voice
# Running → Model: cohere, Prompt: analyst_voice
# Running → Model: llama, Prompt: analyst_voice
# Running → Model: mistral, Prompt: analyst_voice

# %%
for result in all_outputs:
    print(f"\n\nPrompt: {result['prompt'].upper()} | Model: {result['model'].upper()}")
    print("-" * 80)
    print(result['response'])
# Out:
# Prompt: DEFAULT | Model: GEMINI
# --------------------------------------------------------------------------------
# Here's a breakdown of the latest AI-related developments for Apple and Nvidia, and their potential impact on stock prices:
#
# **Apple (AAPL):**
#
# *   **AI Expansion in China:** Apple is partnering with Alibaba and considering Baidu to enhance its AI capabilities in China. This is seen as a strategy to regain market share lost to Huawei and drive iPhone upgrades through "Apple Intelligence." Wedbush maintains an "Outperform" rating with a $325 price target, expecting AI-driven growth in China starting in the June quarter.
# *   **New Product Launch with AI and In-House Modem:** Apple is teasing a new product launch, expected around February 19, featuring "Apple Intelligence" and the A18 chip. This device will also be Apple's first with an in-house cellular modem chip.
# *   **AI Integration:** Apple is integrating AI across its device ecosystem and developing "Apple Intelligence" with specialized AI chips focused on on-device machine learning and privacy-preserving AI applications.
# *   **Stock Impact:** Analysts are overhauling Apple's stock price targets after a record Q1 earnings. Wedbush is optimistic about AI-driven developments and upcoming iPhone releases.
#
# **Nvidia (NVDA):**
#
# *   **Dominance in AI Chips:** Nvidia dominates the AI chip market with its GPUs, considered the standard for AI computing. CEO Jensen Huang projects AI could generate $100 trillion in economic value.
# *   **Competition:** Nvidia faces competition from AMD (with its MI300 AI accelerators) and Intel (with its Gaudi processors).
# *   **Hardware-Software Integration:** BofA emphasizes Nvidia's advantage lies in its hardware-software integration for AI performance.
# *   **Stake in Arm Holdings Slashed:** Nvidia reduced its stake in Arm Holdings by 44%. This could be related to Arm's potential move to compete directly with its licensing customers, including Nvidia, by designing and selling its own processors.
# *   **New Investments:** Nvidia unveiled a new stake in China-based WeRide (autonomous vehicles) and Nebius Group (AI-focused tech group).
# *   **Q4 Earnings:** Nvidia is expected to report earnings on February 26. Analysts anticipate a slight earnings beat for fiscal Q4, but the first-quarter outlook faces pressures related to Blackwell architecture implementation, weakening Hopper-based chip sales, and China trade limitations. BofA maintains a positive view on Nvidia, rating it as a top selection in its sector.
# *   **Valuation:** Nvidia's valuation is at the lower end of its historical range.
# *   **GTC Conference:** The upcoming GTC conference on March 17 is a potential catalyst, with expected chip reveals and expansion into robotics and quantum computing.
# *   **Stock Impact:** Despite some near-term concerns, analysts remain optimistic about Nvidia's long-term potential due to its dominance in AI chips, hardware-software integration, and expansion into new areas like robotics and quantum computing. Nvidia's stock is comparatively cheap to other big tech stocks and looks primed to soar after Feb 26.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: DEFAULT | Model: COHERE
# --------------------------------------------------------------------------------
# Apple's (AAPL) AI initiatives include partnerships with Alibaba and potential collaboration with Baidu, enhancing its AI capabilities in China. They also plan to expand Apple Intelligence globally. Their focus on AI and upcoming product launches is positive, despite a slight revenue dip in the past quarter. Meanwhile, Nvidia (NVDA), the dominant AI chipmaker, is preparing for its Q4 earnings report on February 26th. They expect a slight earnings increase but face challenges due to China restrictions, Hopper chip demand, and the transition to Blackwell chips. Nvidia's shares were affected by the rise of China-based DeepSeek but have since recovered. Both stocks are anticipated to benefit from the growing AI sector.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: DEFAULT | Model: LLAMA
# --------------------------------------------------------------------------------
# Based on recent news, Apple is expanding its AI capabilities in China through partnerships with Alibaba and a potential collaboration with Baidu. Apple's AI-driven developments, including the upcoming iPhone 16 and iPhone 17, are expected to drive growth. Meanwhile, Nvidia is dominating the AI chip market, but faces challenges from emerging rivals like Arm Holdings, which is planning to design and sell its own line of processors. Nvidia's Q4 earnings are expected to be strong, but its first-quarter outlook may face pressure due to the transition to Blackwell chips and China restrictions. Billionaire Israel Englander has reduced his stake in Nvidia, while increasing his position in AppLovin, an AI stock that has surged 1,180% since January 2024.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: DEFAULT | Model: MISTRAL
# --------------------------------------------------------------------------------
# Here’s a concise summary of the latest developments from **Apple (AAPL)** and **Nvidia (NVDA)** related to AI and their impact on stock prices:
#
# ### **Apple (AAPL)**
# 1. **AI Expansion in China**:
#    - Apple is partnering with **Alibaba** and exploring a collaboration with **Baidu** to enhance AI capabilities in China, aiming to restore market share lost to Huawei.
#    - **Apple Intelligence** (its generative AI initiative) is expected to launch in China by April/May 2025, potentially driving iPhone upgrades and ecosystem growth.
#    - Despite a **1% YoY drop in iPhone revenue** ($69.14B vs. $71.04B expected), analysts like **Wedbush** remain bullish, maintaining an **Outperform rating** and a **$325 price target**.
#
# 2. **New Product Launch Teased**:
#    - Apple hinted at a new product (possibly the **iPhone 16**) with **AI and in-house modem** capabilities, featuring the **A18 chip** and **Apple Intelligence**.
#    - The product may mark the end of the home button, signaling a major design shift.
#
# 3. **Profitability & Stock Performance**:
#    - Apple ranks **2nd among the most profitable tech stocks**, with strong margins (32% operating, 24% net).
#    - **Q1 2025 results** showed **4% YoY sales growth**, driven by services (+14% YoY) and Mac/iPad sales (+15% each).
#    - **Morgan Stanley** predicts strong demand for the **iPhone SE 4**, with 15M shipments expected in FY 2025.
#
# ---
#
# ### **Nvidia (NVDA)**
# 1. **Earnings & Market Position**:
#    - **Bank of America (BofA)** expects Nvidia to **beat Q4 earnings** (Feb. 26) but warns of near-term challenges:
#      - **Blackwell chip transition**, **declining Hopper chip demand**, and **China trade restrictions**.
#    - Nvidia remains a **top sector pick** due to its **hardware-software integration** and AI leadership.
#    - **Valuation**: Trading at **31x 2025 earnings** (lower end of historical range).
#
# 2. **AI Arms Race & Investments**:
#    - Nvidia **reduced its stake in Arm Holdings** (44% cut) amid Arm’s push into direct chip competition.
#    - **New investments** in **WeRide (autonomous vehicles)** and **Nebius Group (AI-focused tech)**.
#    - **Exited stakes** in **SoundCloud** and **Serve Robotics**.
#
# 3. **Stock Performance & Outlook**:
#    - **Billionaire Israel Englander** sold **10% of his Nvidia stake** but kept it as his **5th-largest holding**.
#    - **Analysts predict strong Q4 results** ($37.5B revenue expected, 70% YoY growth).
#    - **GTC Conference (March 17)** could be a catalyst with new chip announcements (GB300, Rubin) and expansions into **robotics and quantum computing**.
#
# ---
#
# ### **Stock Price Impact**
# - **Apple (AAPL)**: Positive sentiment due to AI expansion, new product teases, and strong profitability.
# - **Nvidia (NVDA)**: Mixed near-term outlook but long-term optimism due to AI dominance and upcoming catalysts.
#
# Both companies are key players in the AI revolution, with Apple focusing on **on-device AI** and Nvidia leading in **AI infrastructure**. Investors should watch for **Q4 earnings (NVDA, Feb. 26)** and **Apple’s AI rollout in China (April/May 2025)**.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: BULLET_SUMMARY | Model: GEMINI
# --------------------------------------------------------------------------------
# Here's a summary of the key takeaways from the financial news articles related to Apple and Nvidia's AI developments and their impact on stock prices:
#
# **Apple (AAPL):**
#
# *   **AI Expansion in China:** Apple is partnering with Alibaba and exploring a collaboration with Baidu to improve AI capabilities in China. This is seen as a strategy to regain market share lost to Huawei.
# *   **Apple Intelligence as a Driver:** Analysts believe "Apple Intelligence" will drive iPhone upgrades, potentially boosting revenue. Aiming for China AI capability by April or May.
# *   **New Product Launch with AI and In-House Modem:** Apple is teasing a new product launch expected to feature "Apple Intelligence," the A18 chip (also expected in iPhone 16), and its first in-house cellular modem chip.
# *   **Analyst Ratings:**
#     *   Wedbush maintains an "Outperform" rating on Apple with a $325 price target.
#     *   Morgan Stanley analyst reaffirmed an "Overweight" rating and maintained a $275 price target.
# *   **Integration of AI:** The company is integrating AI across its device ecosystem, with a focus on on-device machine learning and privacy-preserving AI applications.
#
# **Nvidia (NVDA):**
#
# *   **Dominance in AI Chips:** Nvidia is the dominant player in the AI chip market, with its GPUs powering most major AI applications and cloud services. Their first-mover advantage and software ecosystem make it a standard for AI computing.
# *   **Earnings Beat Expected, But Near-Term Challenges:** Bank of America expects Nvidia to deliver a slight earnings beat for its fiscal Q4 (results on Feb 26). However, they caution about challenges for the first quarter outlook due to the Blackwell architecture implementation, Hopper-based chip sales weakening, and China trade limitations.
# *   **Nvidia vs. AMD:** Advanced Micro Devices (AMD) challenges Nvidia's dominance with its MI300 AI accelerators.
# *   **Computing Platform:** BofA emphasizes that Nvidia positions itself as a computing platform (hardware-software integration), not just a chip producer, which is a key advantage.
# *   **GTC Conference as Potential Catalyst:** Nvidia's upcoming GTC conference (March 17) is expected to be a major catalyst, with potential chip reveals and expansion into robotics and quantum computing.
# *   **Strategic Investment Portfolio:**
#     *   Reduced stake in Arm Holdings: Reflecting Arm's interest in direct competition with chip designers.
#     *   New stake in China-based WeRide: A client using Nvidia's software and GPUs for autonomous vehicles.
#     *   Closed out holdings in SoundCloud and Serve Robotics.
# *   **Earnings Expectations and Valuation:**
#     *   Analysts expect strong Q4 results, with revenues rising around 66% and net income surging 62%.
#     *   Analysts believe Nvidia will exceed their expected revenue projection for Q4.
#     *   Some believe the stock is comparatively cheap, considering growth prospects. Trading at 30 times forward earnings while the revenue growth for FY26 is expected to be 52%.
# *   **Competition and Growth:** Competition is heating up (DeepSeek). Investment in compute efficiency is important.
# *   **Analyst Ratings and Actions:**
#     *   BofA maintains strong positive views about Nvidia's future outlook while continuing to rate it as the top selection in its industry sector.
#     *   Billionaire Israel Englander sold down his position in the fourth quarter.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: BULLET_SUMMARY | Model: COHERE
# --------------------------------------------------------------------------------
# - Apple is partnering with Alibaba and exploring a collaboration with Baidu to enhance its AI capabilities in China. The move aims to increase market share in China, with the potential for 25% of the world's population accessing AI via Apple devices.
# - Apple is planning a new product launch on February 19, teased by CEO Tim Cook as the "newest member of the family." The product may feature Apple Intelligence and the A18 chip.
# - Nvidia dominates the AI chip market, with its graphics processing units (GPUs) powering major AI applications. The company is positioned as a computing platform, differentiating itself in the AI space.
# - Bank of America predicts a slight earnings increase for Nvidia's fiscal fourth quarter, ending February 26, but anticipates challenges in the first quarter. The stock is valued at the lower end of its historical range.
# - Nvidia's shares dropped following the emergence of China-based DeepSeek, a low-cost AI chatbot, but have since recovered. The company is also reducing its stake in Arm Holdings due to the latter's expansion plans.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: BULLET_SUMMARY | Model: LLAMA
# --------------------------------------------------------------------------------
# Here are the key takeaways related to Apple and Nvidia's latest developments in AI and their impact on stock prices:
#
# * Apple is partnering with Alibaba and considering a collaboration with Baidu to enhance its artificial intelligence capabilities in China, with the goal of creating an ecosystem of AI-powered apps and generating new revenue streams.
# * Apple is working on Apple Intelligence, its generative AI initiative, and is expected to launch new products with AI capabilities, including a potential new device with an in-house cellular modem chip, which could be a game-changer for the company.
# * Nvidia is a leading player in the AI chip market, with its graphics processing units (GPUs) powering most major AI applications and cloud services, and is expected to continue to dominate the market in the near future.
# * Nvidia's stock price has been volatile due to the emergence of new AI players, such as DeepSeek, but analysts believe the company's strong track record and dominance in the AI chip market make it a solid long-term investment.
# * Billionaire Israel Englander has sold down his position in Nvidia, but still holds a significant stake in the company, and has invested in AppLovin, an AI stock that has seen significant growth since early 2024.
# * Nvidia is expected to beat earnings expectations when it reports its fiscal Q4 results on February 26, but analysts are cautious about the company's first-quarter outlook due to challenges such as the transition to Blackwell chips and ongoing restrictions in China.
# * Nvidia's valuation remains attractive, trading at 31x projected 2025 earnings and 24x for 2026, and the company's upcoming GTC conference on March 17 could be a major catalyst for the stock.
#
# Overall, both Apple and Nvidia are well-positioned to benefit from the growing demand for AI technologies, and their investments in AI research and development are expected to drive innovation and growth in the industry. However, the companies also face challenges and uncertainties, such as intense competition, regulatory restrictions, and the need to adapt to rapidly changing technologies and market trends.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: BULLET_SUMMARY | Model: MISTRAL
# --------------------------------------------------------------------------------
# Here are the key takeaways from the financial news related to **Apple (AAPL)** and **Nvidia (NVDA)** and their impact on stock prices:
#
# ### **Apple (AAPL) – AI and Stock Developments**
# - **AI Expansion in China**:
#   - Partnered with **Alibaba** and exploring collaboration with **Baidu** to enhance AI capabilities in China.
#   - Wedbush Securities expects **Apple Intelligence** to drive iPhone upgrades and restore market share lost to Huawei.
#   - AI features expected to launch in China by **April or May 2025**.
#   - **25% of the world’s population** may access AI via Apple devices.
#   - **Stock Impact**: Wedbush maintains an **Outperform rating** with a **$325 price target**.
#
# - **New Product Launch Teased**:
#   - Apple hinted at a new product launch (possibly an **iPhone 16 or 17**) with **Apple Intelligence** and an **in-house modem chip**.
#   - The device may feature the **A18 chip** and eliminate the home button.
#   - **Stock Impact**: Apple ranks **2nd among high-flying AI stocks** but may not be the most promising compared to other AI-focused stocks.
#
# - **Financial Performance**:
#   - **iPhone revenue fell 1% YoY** to **$69.14 billion** (missed expectations of **$71.04 billion**).
#   - **Greater China revenue dropped to $18.51 billion**.
#   - **Services segment grew 14% YoY**, while **Mac and iPad sales rose ~15%**.
#   - **Stock Impact**: Analysts remain optimistic about AI-driven growth, but China remains a challenge.
#
# ### **Nvidia (NVDA) – AI and Stock Developments**
# - **Earnings Expectations**:
#   - **Bank of America (BofA)** expects Nvidia to **beat Q4 earnings** but warns of **near-term challenges**:
#     - **Blackwell chip transition**, **declining Hopper chip demand**, and **China trade restrictions**.
#   - **Q4 revenue forecast**: **$37.5 billion** (70% YoY growth), but analysts expect **73% growth**.
#   - **Stock Impact**: Nvidia trades at **31x 2025 earnings and 24x 2026 earnings**, near the lower end of its historical range.
#
# - **Investment Portfolio Adjustments**:
#   - **Reduced stake in Arm Holdings by 44%** (now holds **1.1 million shares**).
#   - **New investments in WeRide (autonomous vehicles) and Nebius Group (AI-focused tech)**.
#   - **Exited positions in SoundCloud and Serve Robotics**.
#   - **Stock Impact**: Nvidia remains a **top pick** for AI computing, but competition from **DeepSeek and Broadcom** poses risks.
#
# - **Market Sentiment**:
#   - **Billionaire Israel Englander sold 1.1 million NVDA shares** (10% reduction) but still holds it as a **top 5 position**.
#   - **Stock Impact**: Nvidia remains a **key AI leader**, but investors are monitoring **China risks and chip transitions**.
#
# ### **Overall Stock Price Impact**
# - **Apple (AAPL)**:
#   - **Positive**: AI expansion in China, new product launches, strong services growth.
#   - **Negative**: iPhone revenue decline, China market challenges.
#   - **Analyst Outlook**: **Outperform ratings** but mixed on AI vs. traditional growth.
#
# - **Nvidia (NVDA)**:
#   - **Positive**: Strong earnings growth, AI dominance, new investments.
#   - **Negative**: China trade restrictions, competition from DeepSeek, chip transition risks.
#   - **Analyst Outlook**: **Top pick in AI sector**, but near-term volatility expected.
#
# Both companies are **key players in AI**, but **Nvidia faces more near-term risks**, while **Apple’s AI strategy is still in early stages**. Investors should watch **Q4 earnings (Feb. 26 for NVDA)** and **Apple’s AI rollout in China** for further stock movements.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: ANALYST_VOICE | Model: GEMINI
# --------------------------------------------------------------------------------
# Here's a breakdown of the latest AI developments at Apple and Nvidia, and potential impacts on their stock prices:
#
# **Apple (AAPL)**
#
# *   **AI Expansion in China:** Apple is partnering with Alibaba and considering a collaboration with Baidu to enhance its AI capabilities in China. This is seen as a key strategy to regain market share lost to Huawei and drive iPhone upgrades, particularly with the upcoming iPhone 16 and 17 models. Wedbush projects that eventually 25% of the world's population will access AI via Apple devices.
# *   **New Product Launch with AI:** Apple is teasing a new product launch expected to feature "Apple Intelligence" and the A18 chip (likely for the iPhone 16). This device will also be Apple's first with an in-house cellular modem chip.
# *   **Analyst Outlook:** Wedbush maintains an "Outperform" rating on Apple with a price target of $325. Morgan Stanley reaffirmed its "Overweight" rating and a $275 price target, anticipating a strong launch for the iPhone SE 4.
# *   **China Challenges:** Apple's iPhone revenue and revenue from Greater China both declined year-over-year in the last quarter. China continues to be a hurdle.
# *   **Stock Impact:** Apple’s push into AI, especially in China, is perceived as a positive catalyst. Wedbush believes CEO Tim Cook has handled the China strategy well, despite geopolitical concerns. The new product launch with AI features is also expected to be a driver for growth. However, concerns about slowing iPhone sales and challenges in the Chinese market remain.
#
# **Nvidia (NVDA)**
#
# *   **Dominant Position in AI Chips:** Nvidia continues to dominate the AI chip market with its GPUs powering major AI applications and cloud services. Their "first-mover advantage" and software ecosystem are considered key strengths.
# *   **Market Correction:** Nvidia experienced a significant market correction due to the emergence of China-based DeepSeek.
# *   **Stake in ARM Holdings:** Nvidia has reduced its stake in Arm Holdings by 44%. This may reflect Arm's potential move into direct competition with Nvidia, as Arm is considering designing and selling its own line of processors. However, Nvidia did unveil a new stake in China-based WeRide, an autonomous vehicles company that uses Nvidia's software. They also invested in AI-focused tech group Nebius Group. Nvidia closed out prior holdings in Soundcloud and Serve Robotics.
# *   **Earnings Expectations and Potential Risks:** Bank of America (BofA) expects Nvidia to slightly beat earnings expectations for its fiscal fourth quarter (to be reported February 26). However, they also highlight potential challenges to the first-quarter outlook related to the transition to Blackwell chips, weakening Hopper chip sales, and China trade restrictions. Wall Street analysts are convinced that Nvidia undershot its revenue projection and estimate 73% growth on average. Management expects revenue of $37.5 billion, which would indicate 70% year-over-year growth.
# *   **Analyst Outlook:** BofA remains optimistic about Nvidia's long-term potential and maintains its "top sector pick" rating, emphasizing Nvidia's position as a computing platform with hardware-software integration advantages. They also note that Nvidia's valuation is at the lower end of its historical range.
# *   **Upcoming Catalysts:** The GTC conference on March 17 is seen as a major potential catalyst, with expected chip reveals and expansion announcements in robotics and quantum computing.
# *   **Stock Impact:** Nvidia's dominant position in the AI chip market and strong growth prospects continue to be positive drivers for its stock price. However, investors should be aware of potential near-term headwinds related to chip transitions, China trade, and increasing competition.
#
# In conclusion, both companies are heavily involved in AI, but their approaches and challenges differ. Apple is focused on integrating AI into its devices and services, particularly in China. Nvidia is the dominant player in AI chips, but it faces increased competition and potential near-term risks related to its business transitions and geopolitical factors. Investors should weigh these factors when considering the potential impact on each company's stock price.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: ANALYST_VOICE | Model: COHERE
# --------------------------------------------------------------------------------
# Apple's stock price has seen a 1% drop in the last year, underperforming the market's expectations. The company has recently partnered with Alibaba, and plans to collaborate with Baidu, focusing on AI expansion in China. The new AI capabilities are expected to drive iPhone upgrades, with China projected to adopt the technology by April or May. The company's diversification into AI services and software is expected to boost revenue, with its services segment growing significantly.
#
# On the other hand, Nvidia's stock price has advanced 180% since January 2024, amid high demand for its AI platforms. The company dominates the AI chip market, and is expected to report a slight earnings increase in its fiscal fourth quarter on February 26, with analysts predicting a strong performance in the long term. The company positions itself as a computing platform, integrating hardware and software, which is expected to be a key advantage in the AI space.
#
# Despite the recent sell-off triggered by the emergence of China-based DeepSeek, Nvidia's shares are expected to soar after the earnings report on February 26, presenting a buying opportunity for investors. The company's diverse product portfolio and strong market position make it an attractive investment.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: ANALYST_VOICE | Model: LLAMA
# --------------------------------------------------------------------------------
# Based on the news provided, here are the latest developments from Apple and Nvidia related to AI and their impact on stock prices:
#
# **Apple:**
#
# 1. Apple has partnered with Alibaba and is exploring a potential collaboration with Baidu to enhance its artificial intelligence capabilities in China.
# 2. The company is developing Apple Intelligence, its generative AI initiative, along with specialized AI chips focusing on on-device machine learning and privacy-preserving AI applications.
# 3. Apple is expected to launch a new product with AI and in-house modem capabilities.
# 4. The company's service segment, which includes subscriptions and digital content, is expected to grow significantly, providing a steady revenue stream.
# 5. Apple's shares are considered relatively cheap, with a forward price-to-earnings ratio of 21, compared to the S&P 500.
#
# **Nvidia:**
#
# 1. Nvidia is expected to beat earnings expectations when it reports its fiscal Q4 results on February 26.
# 2. The company's Blackwell GPU handles AI training up to four times faster and AI inference up to 30 times faster than its previous Hopper GPU.
# 3. Nvidia's valuation remains attractive, trading at 31x projected 2025 earnings and 24x for 2026, on the lower end of its historical range.
# 4. The company's upcoming GTC conference on March 17 could be a major catalyst, with expected unveilings of new chips and expansion plans into robotics and quantum computing.
# 5. Billionaire Israel Englander, CEO of hedge fund Millennium Management, sold down his position in Nvidia in the fourth quarter, but still holds a significant stake in the company.
#
# **Impact on Stock Prices:**
#
# 1. Apple's stock price has been relatively stable, with a slight increase in recent days.
# 2. Nvidia's stock price has been more volatile, with a significant drop in late January due to the emergence of China-based DeepSeek, but has since recovered some of its losses.
# 3. Nvidia's stock is expected to see some volatility after its earnings report, but remains a top pick for many analysts due to its strong growth prospects and attractive valuation.
#
# Overall, both Apple and Nvidia are well-positioned to benefit from the growing demand for AI technology, with Apple focusing on developing its own AI capabilities and Nvidia leading the charge in AI chipmaking. However, Nvidia's stock price may be more volatile in the short term due to the emergence of new competitors and the company's high valuation.
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
#
#
# Prompt: ANALYST_VOICE | Model: MISTRAL
# --------------------------------------------------------------------------------
# ### **Latest Developments from Apple (AAPL) and Nvidia (NVDA) Related to AI and Their Impact on Stock Prices**
#
# #### **Apple (AAPL) – AI Expansion and Market Strategy**
# 1. **AI Partnerships in China**
#    - Apple has partnered with **Alibaba (BABA)** and is exploring a collaboration with **Baidu (BIDU)** to enhance its AI capabilities in China.
#    - Wedbush Securities expects Apple Intelligence (AI-driven features) to be available in China by **April or May 2025**, which could help restore market share lost to Huawei.
#    - The firm projects that **25% of the world’s population will access AI via an Apple device**, driving growth in China despite geopolitical challenges.
#
# 2. **Upcoming Product Launch**
#    - Apple is teasing a new product launch (likely the **iPhone 16 or 17**) with **AI and an in-house modem**, which could boost iPhone upgrades.
#    - The new device may feature **Apple Intelligence, the A18 chip, and the end of the home button**, signaling a major hardware and software integration push.
#
# 3. **Financial Performance & Analyst Sentiment**
#    - Apple reported a **1% YoY decline in iPhone revenue ($69.14B vs. $71.04B expected)** but saw **14% growth in Services revenue**.
#    - Wedbush maintains an **Outperform rating** with a **$325 price target**, citing strong AI-driven growth potential.
#
# #### **Nvidia (NVDA) – AI Leadership and Market Challenges**
# 1. **Earnings Expectations & Near-Term Risks**
#    - Nvidia is expected to **beat Q4 earnings (Feb. 26, 2025)** but faces challenges in **Blackwell chip adoption, weakening Hopper sales, and China trade restrictions**.
#    - Bank of America (BofA) remains bullish long-term, calling Nvidia a **computing platform** rather than just a chipmaker.
#
# 2. **Investment Portfolio Adjustments**
#    - Nvidia **reduced its stake in Arm Holdings by 44%**, possibly due to Arm’s shift toward **designing its own processors** (competing with Nvidia, Apple, and Qualcomm).
#    - The company also **divested from SoundCloud (SOUN) and Serve Robotics (SERV)** but **increased stakes in WeRide (autonomous vehicles) and Nebius Group (AI-focused tech)**.
#
# 3. **Market Position & Valuation**
#    - Nvidia’s **GPUs dominate AI chip market share (84%)**, with strong demand from **Meta, Alphabet, and other tech giants**.
#    - Despite a **10%+ pullback from 2025 highs**, Nvidia trades at **30x forward earnings**, making it **cheaper than Apple (AAPL) and Microsoft (MSFT)**.
#    - Analysts expect **strong Q4 results and a potential rally post-earnings**.
#
# #### **Stock Price Impact**
# - **Apple (AAPL):**
#   - Positive sentiment due to **AI-driven growth, China expansion, and upcoming product launches**.
#   - Potential upside if **iPhone 16/17 adoption and Apple Intelligence adoption exceed expectations**.
#
# - **Nvidia (NVDA):**
#   - Near-term volatility due to **China restrictions and chip transition risks**.
#   - Long-term bullish outlook due to **AI hardware dominance, strong earnings growth, and potential GTC conference catalysts (March 17, 2025)**.
#
# ### **Conclusion**
# - **Apple** is positioning itself as a major AI player, particularly in China, with strong analyst support.
# - **Nvidia** remains the **AI hardware leader** but faces short-term challenges; however, its long-term growth prospects remain robust.
# - Both stocks are well-positioned for AI-driven growth, with **NVDA offering higher near-term volatility and AAPL providing more stability**.
#
# Would you like a deeper analysis on any specific aspect?
#
# Sources:
# https://finance.yahoo.com/news/apple-partners-alibaba-eyes-baidu-150006091.html
# https://finance.yahoo.com/news/apple-inc-aapl-teases-product-182528020.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/m/aa3b145b-444f-3b8d-a721-fb8610c18331/25-top-ai-stocks-that-could.html
# https://finance.yahoo.com/video/race-ai-only-faster-cheaper-163531833.html
# https://finance.yahoo.com/m/f8b3f9c9-1d15-3c1b-91e5-caeae9dfdb9b/prediction%3A-these-2-quantum.html
# https://finance.yahoo.com/news/apple-inc-aapl-most-profitable-122451503.html
# https://finance.yahoo.com/news/nvidia-set-beat-earnings-near-174914435.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html
# https://finance.yahoo.com/m/de81d50b-018c-3496-a737-b89efc80b48a/ai-stock-sell-off%3A-1.html
# https://finance.yahoo.com/m/b022b996-c9f0-31ee-9d07-27c6c485ef3a/billionaire-israel-englander.html
# https://finance.yahoo.com/news/nvidia-set-beat-q4-earnings-175151694.html
# https://finance.yahoo.com/m/f261d9f7-d49b-34a9-b8d3-0a6b1ad256d7/nvidia-slashes-stake-in.html

# %%
df = pd.DataFrame(all_outputs)
df.to_csv("model_comparison.csv", index=False)
df.head()
# Out:
#      model          prompt                                           response
# 0   gemini         default  Here's a breakdown of the latest AI-related de...
# 1   cohere         default  Apple's (AAPL) AI initiatives include partners...
# 2    llama         default  Based on recent news, Apple is expanding its A...
# 3  mistral         default  Here’s a concise summary of the latest develop...
# 4   gemini  bullet_summary  Here's a summary of the key takeaways from the...
